# %%
import pandas as pd

def excel_to_csv_pandas(excel_path, csv_path):
    # Excel dosyasını oku
    xls = pd.ExcelFile(excel_path)
    
    # İkinci sayfanın adını al
    sheet_name = xls.sheet_names[1]  # 0-indexed olduğundan 1, ikinci sayfayı temsil eder

    # İkinci sayfayı DataFrame olarak oku
    df = pd.read_excel(xls, sheet_name)

    # CSV dosyasına kaydet
    df.to_csv(csv_path, index=False)

# Kullanım:
excel_to_csv_pandas('ZIP_Locale_Detail USA.xlsx', 'output.csv')
# Out:
# C:\Users\furka\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

base_url = "https://www.cars.com/sitemap/city-listings/"

# Selenium için Firefox driverını başlat
driver = webdriver.Firefox()

# Verilen URL'yi aç
driver.get(base_url)

# BeautifulSoup ile sayfanın HTML içeriğini parse et
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Tüm "shopping-city" linklerini topla
city_links = ['https://www.cars.com'+a['href'] for a in soup.find_all('a', attrs={"data-linkname": "shopping-city"})]
print(city_links)
zip_values = []

# Her bir şehir linki için işlem yap
for link in city_links:
    driver.get(link)
    time.sleep(3)  # Sayfanın tamamen yüklenmesini beklemek için

    # Zip input değerini al
    zip_input = driver.find_element(By.ID, 'zip-input')
    print(zip_input.get_attribute('value'))
    zip_values.append(zip_input.get_attribute('value'))

driver.close()

print(zip_values)
# Out:
# ['https://www.cars.com/shopping/albany-ny/', 'https://www.cars.com/shopping/albuquerque-nm/', 'https://www.cars.com/shopping/anchorage-ak/', 'https://www.cars.com/shopping/arlington-tx/', 'https://www.cars.com/shopping/asheville-nc/', 'https://www.cars.com/shopping/athens-ga/', 'https://www.cars.com/shopping/atlanta-ga/', 'https://www.cars.com/shopping/austin-tx/', 'https://www.cars.com/shopping/bakersfield-ca/', 'https://www.cars.com/shopping/ballwin-mo/', 'https://www.cars.com/shopping/baltimore-md/', 'https://www.cars.com/shopping/baton_rouge-la/', 'https://www.cars.com/shopping/baytown-tx/', 'https://www.cars.com/shopping/bedford-oh/', 'https://www.cars.com/shopping/bellevue-wa/', 'https://www.cars.com/shopping/birmingham-al/', 'https://www.cars.com/shopping/boise-id/', 'https://www.cars.com/shopping/brandon-ms/', 'https://www.cars.com/shopping/brooklyn-ny/', 'https://www.cars.com/shopping/buena_park-ca/', 'https://www.cars.com/shopping/centennial-co/', 'https://www.cars.com/shopping/center_line-mi/', 'https://www.cars.com/shopping/cerritos-ca/', 'https://www.cars.com/shopping/charlotte-nc/', 'https://www.cars.com/shopping/chattanooga-tn/', 'https://www.cars.com/shopping/chicago-il/', 'https://www.cars.com/shopping/cincinnati-oh/', 'https://www.cars.com/shopping/cleveland-oh/', 'https://www.cars.com/shopping/colorado_springs-co/', 'https://www.cars.com/shopping/columbia-sc/', 'https://www.cars.com/shopping/columbus-oh/', 'https://www.cars.com/shopping/concord-ca/', 'https://www.cars.com/shopping/conway-ar/', 'https://www.cars.com/shopping/corpus_christi-tx/', 'https://www.cars.com/shopping/dallas-tx/', 'https://www.cars.com/shopping/danvers-ma/', 'https://www.cars.com/shopping/denver-co/', 'https://www.cars.com/shopping/des_moines-ia/', 'https://www.cars.com/shopping/el_cajon-ca/', 'https://www.cars.com/shopping/el_paso-tx/', 'https://www.cars.com/shopping/elk_grove-ca/', 'https://www.cars.com/shopping/englewood-co/', 'https://www.cars.com/shopping/escondido-ca/', 'https://www.cars.com/shopping/evansville-in/', 'https://www.cars.com/shopping/fairfield-oh/', 'https://www.cars.com/shopping/fort_myers-fl/', 'https://www.cars.com/shopping/fort_wayne-in/', 'https://www.cars.com/shopping/fort_worth-tx/', 'https://www.cars.com/shopping/franklin-tn/', 'https://www.cars.com/shopping/frederick-md/', 'https://www.cars.com/shopping/freehold-nj/', 'https://www.cars.com/shopping/fremont-ca/', 'https://www.cars.com/shopping/fresno-ca/', 'https://www.cars.com/shopping/gainesville-fl/', 'https://www.cars.com/shopping/gilbert-az/', 'https://www.cars.com/shopping/glendale-ca/', 'https://www.cars.com/shopping/grand_rapids-mi/', 'https://www.cars.com/shopping/grapevine-tx/', 'https://www.cars.com/shopping/green_bay-wi/', 'https://www.cars.com/shopping/greensboro-nc/', 'https://www.cars.com/shopping/greenville-sc/', 'https://www.cars.com/shopping/hagerstown-md/', 'https://www.cars.com/shopping/henderson-nv/', 'https://www.cars.com/shopping/honolulu-hi/', 'https://www.cars.com/shopping/huntington_beach-ca/', 'https://www.cars.com/shopping/indianapolis-in/', 'https://www.cars.com/shopping/jackson-ms/', 'https://www.cars.com/shopping/jacksonville-fl/', 'https://www.cars.com/shopping/jersey_city-nj/', 'https://www.cars.com/shopping/johnson_city-tn/', 'https://www.cars.com/shopping/kansas_city-mo/', 'https://www.cars.com/shopping/katy-tx/', 'https://www.cars.com/shopping/kirkland-wa/', 'https://www.cars.com/shopping/knoxville-tn/', 'https://www.cars.com/shopping/lafayette-la/', 'https://www.cars.com/shopping/lakeland-fl/', 'https://www.cars.com/shopping/lakewood-co/', 'https://www.cars.com/shopping/las_vegas-nv/', 'https://www.cars.com/shopping/laurel-md/', 'https://www.cars.com/shopping/lincoln-ne/', 'https://www.cars.com/shopping/little_rock-ar/', 'https://www.cars.com/shopping/longmont-co/', 'https://www.cars.com/shopping/los_angeles-ca/', 'https://www.cars.com/shopping/louisville-ky/', 'https://www.cars.com/shopping/lubbock-tx/', 'https://www.ca ...
# 12206
# 87151
# 99577
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\furka\OneDrive\Masaüstü\Python_projects\cars.com Scraping\cars.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#X11sZmlsZQ%3D%3D?line=22'>23</a> for link in city_links:
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#X11sZmlsZQ%3D%3D?line=23'>24</a>     driver.get(link)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#X11sZmlsZQ%3D%3D?line=24'>25</a>     time.sleep(3)  # Sayfanın tamamen yüklenmesini beklemek için
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#X11sZmlsZQ%3D%3D?line=26'>27</a>     # Zip input değerini al
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#X11sZmlsZQ%3D%3D?line=27'>28</a>     zip_input = driver.find_element(By.ID, 'zip-input')
#
# KeyboardInterrupt:

# %% [markdown]
# _____

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
url = "https://www.cars.com/shopping/results/"

params = {
    "page": "82",
    "page_size": "100",
    "zip": "12206"
}

payload = {}
headers = {
  'authority': 'www.cars.com',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'tr-TR,tr;q=0.9',
  'cache-control': 'max-age=0',
  'cookie': 'ToyotaNewAd=false; CARS_als_loaded=true; CARS_experience_testing={"session_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026","tnt_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026.34_0"}; CARS_has_visited=; CARS_logged_in=false; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; bm_sz=F2CC5771C85DE8C2AA6B4A355267D36F~~3293762~3618116; CARS_navClick=; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; s_ecid=MCMID%7C23143105766679683772866057691083138844; AMCVS_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1; _cs_mk_aa=0.022461580964973082_1696688893476; AMCV_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1176715910%7CMCIDTS%7C19638%7CMCMID%7C23143105766679683772866057691083138844%7CMCAID%7CNONE%7CMCOPTOUT-1696696091s%7CNONE%7CMCAAMLH-1697293691%7C6%7CMCAAMB-1697293691%7Cj8Odv6LonN4r3an7LhD3WZrU1bUpAkFkkiY1ncBR96t2PTI%7CMCSYNCSOP%7C411-19645%7CvVersion%7C5.4.0; s_lv_s=First%20Visit; s_inv=0; s_cc=true; _gid=GA1.2.849265699.1696688897; _gcl_au=1.1.2097986781.1696688897; _pin_unauth=dWlkPVltUXdNamN6TmpVdE5tVmtZaTAwTkdSaExUZ3pNVFF0WVdOak5UUXdNbVE0WW1ZMw; ToyotaNewAd=false; di_roxanne__visit_id=8057982562; di_roxanne__visitor_id=12250551822; _aeaid=55e8b292-2da5-4c84-913c-bb19c0ceac90; aelastsite=RVHvE4glMR0sC5iYWBair1aiHO0Ez37924foGSUCRDBlkWrbrSt4Qc%2BBnB7QmaV7; aelreadersettings=%7B%22c_big%22%3A0%2C%22rg%22%3A0%2C%22memph%22%3A0%2C%22contrast_setting%22%3A0%2C%22colorshift_setting%22%3A0%2C%22text_size_setting%22%3A0%2C%22space_setting%22%3A0%2C%22font_setting%22%3A0%2C%22k%22%3A0%2C%22k_disable_default%22%3A0%2C%22hlt%22%3A0%2C%22disable_animations%22%3A0%2C%22display_alt_desc%22%3A0%7D; iovoxMCM=other; iovox_sea=eyJmaXJzdF92aXNpdCI6IjIwMjMtMTAtMDdUMTQ6MzA6MDcuOTczWiIsInJlZmVyZXJfcGFnZSI6Imh0dHBzOi8vd3d3LmNhcnMuY29tL3Nob3BwaW5nL2FsYmFueS1ueS8iLCJmaXJzdF9wYWdlIjoiaHR0cHM6Ly93d3cuY2Fycy5jb20vdmVoaWNsZWRldGFpbC9jZjNiMDVkMS1hMjE1LTRiNjAtYTAzYi0yNDU1NDIxZDkzNGMvIn0=; iovox_id=e7697b26-63e4-48db-a842-dfdf013730f2; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~0~...~-1~-1~-1; s_sq=%5B%5BB%5D%5D; _gat_gtag_UA_50492232_1=1; CARS_marketing_source=SFMyNTY.....aG3_Y2mc29_YmtzeWsGdCvPXW-oC-hOpFw2O_r-69oQ; CARS_search_session=SFMyNTY..rhE1p9xZ_mITkZZiRJJhTJQ4XgeezKHRvGXVtSlZu40; _cars_web_key=SFMyNTY.....nvHHdC7NacptxfF_c5V0T7dzpLgEo_6nslJ8p9qXaak; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAnuAMPiKAQAALEWkChXCp4+yh3LfI5kwGkGnfhDrKiijJJ9bOk6zRqaCrcqrHrIJUvfQI1K974MTvwv1NkQ2spiVem5G4H4R2uEs29ogepo5i9Bu0G7v0AFVsKFnOlgjaawa03fpC1b8qzc+vgPIbnWRXGsXnOdJXek65hNHysf+sFyNguZtryXgHO1zjTwGPsX11PowBZXeYqR0NKltEJDG9OIwgnEo8v5YJ2gaPSVakD7ZpaZ+U+8=~1; _ga=GA1.1.1704964458.1696688897; _uetsid=bf8b9a60651d11ee8a3211461756d986; _uetvid=bf8baa30651d11ee8cbea3e331cc35c4; _tq_id.TV-09274518-1.6c07=8508f3f072268ee7.1696688900.0.1696690620..; QSI_HistorySession=https%3A%2F%2Fwww.cars.com%2Fvehicledetail%2F2c4e260f-99b7-45c9-9717-abf38d63d7ff%2F~1696689479141%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690593284%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F~1696690600438%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690602829%7Chttps%3A%2F%2Fwww.cars.com%2F~1696690619648%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2Freviews%2F~1696690620770; smtrrmkr=638322874255987464%5E018b0a8a-05ee-442f-9f6a-bc1ad33a3e3d%5E018b0a8a-05ee-4010-a77c-adff1d21cba3%5E0%5E178.233.76.50; s_lv=1696690624430; s_tslv=1696690624430; _ga_LGBH9NL64W=GS1.1.1696688896.1.1.1696690635.26.0.0; _ga_0SVYF8BFF1=GS1.1.1696688896.1.1.1696690635.0.0.0; s_tp=30139; s_ppv=shopping%2Fsearch-results%2C2%2C2%2C746; _dd_s=rum=0&expire=1696691555863; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~-1~...~0~-1~-1; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; bm_mi=4DB48FCEA082564929365C96D90117DC~~1; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAi4GMfiKAQAAx/iyChU8DMxbL4kPIeroqvx9c1HkhIhOGbQ9q0CFOO2JWbt4gl9MknpZSkQHgyt5CkAItLu+6SoJJJNX38US2dxedDzjEFCPmtoUlG34UZ6T/YSkUL02/NifWUo2KhFwq+AP4I02GZhztgUJ/KdnazYofBXW55PDnmYhAHetRNelepWF0tlc3A/SIYbvtxezuoLiueQADTbLMHhhnePZJKYkNsbrG66kyKTmHIIqtoI=~1; bm_sz=36F39175F590614E19CD893EB952708F~~4342835~3683894; CARS_logged_in=false; CARS_marketing_source=SFMyNTY.....LfRqyl6qj4-emTLjTdmMZw6hsATpoh8pq1fMG8Cra34; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; _cars_web_key=SFMyNTY.....q35LEd4bukElSMyhnvFvEA0rws7y8dKVWxpcXHiR6Gs',
  'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0'
}

response = requests.request("GET", url, headers=headers, params=params, data=payload)

soup = BeautifulSoup(response.content, 'html.parser')

# %%
a = soup.find("cars-datalayer", attrs={"store" : "als"})

data = json.loads(a.text)

# %%
customer_ids = set()
for entry in data:
    for vehicle in entry['vehicle_array']:
        customer_ids.add(vehicle['customer_id'])

print(customer_ids)
# Out:
# {'4375', '109376', '5375060', '6039', '6062014', '5397841', '186578'}

# %% [markdown]
# CLASSLI

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

class CarsScraper:
    def __init__(self, headers):
        self.headers = headers
        self.base_url = "https://www.cars.com/shopping/results/"
        self.dealer_url = "https://www.cars.com/dealers/{customer_id}"
        self.zip_codes = self.load_zip_codes()

    def load_zip_codes(self):
        # ZIP kodlarını CSV dosyasından oku
        df = pd.read_csv('results.csv')
        return df['ZIP Value'].tolist()

    def get_customer_ids(self, zip_code, page=1, page_size=100):
        params = {
            "page": str(page),
            "page_size": str(page_size),
            "zip": str(zip_code)
        }
        response = requests.request("GET", self.base_url, headers=self.headers, params=params)
        soup = BeautifulSoup(response.content, 'html.parser')
        a = soup.find("cars-datalayer", attrs={"store": "als"})
        data = json.loads(a.text)

        customer_ids = set()
        for entry in data:
            for vehicle in entry['vehicle_array']:
                customer_ids.add(vehicle['customer_id'])
        return customer_ids

    def request_dealer_page(self, customer_id):
        print(customer_id)
        # url = self.dealer_url.format(customer_id=customer_id)
        # response = requests.request("GET", url, headers=self.headers)
        # İsteğin sonuçlarını işleme
        # ...

    def run(self):
        for zip_code in self.zip_codes:
            customer_ids = self.get_customer_ids(zip_code)
            for customer_id in customer_ids:
                self.request_dealer_page(customer_id)

# Headers tanımı (Örneğin: User-Agent, vs.)
headers = {
  'authority': 'www.cars.com',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'tr-TR,tr;q=0.9',
  'cache-control': 'max-age=0',
  'cookie': 'ToyotaNewAd=false; CARS_als_loaded=true; CARS_experience_testing={"session_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026","tnt_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026.34_0"}; CARS_has_visited=; CARS_logged_in=false; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; bm_sz=F2CC5771C85DE8C2AA6B4A355267D36F~~3293762~3618116; CARS_navClick=; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; s_ecid=MCMID%7C23143105766679683772866057691083138844; AMCVS_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1; _cs_mk_aa=0.022461580964973082_1696688893476; AMCV_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1176715910%7CMCIDTS%7C19638%7CMCMID%7C23143105766679683772866057691083138844%7CMCAID%7CNONE%7CMCOPTOUT-1696696091s%7CNONE%7CMCAAMLH-1697293691%7C6%7CMCAAMB-1697293691%7Cj8Odv6LonN4r3an7LhD3WZrU1bUpAkFkkiY1ncBR96t2PTI%7CMCSYNCSOP%7C411-19645%7CvVersion%7C5.4.0; s_lv_s=First%20Visit; s_inv=0; s_cc=true; _gid=GA1.2.849265699.1696688897; _gcl_au=1.1.2097986781.1696688897; _pin_unauth=dWlkPVltUXdNamN6TmpVdE5tVmtZaTAwTkdSaExUZ3pNVFF0WVdOak5UUXdNbVE0WW1ZMw; ToyotaNewAd=false; di_roxanne__visit_id=8057982562; di_roxanne__visitor_id=12250551822; _aeaid=55e8b292-2da5-4c84-913c-bb19c0ceac90; aelastsite=RVHvE4glMR0sC5iYWBair1aiHO0Ez37924foGSUCRDBlkWrbrSt4Qc%2BBnB7QmaV7; aelreadersettings=%7B%22c_big%22%3A0%2C%22rg%22%3A0%2C%22memph%22%3A0%2C%22contrast_setting%22%3A0%2C%22colorshift_setting%22%3A0%2C%22text_size_setting%22%3A0%2C%22space_setting%22%3A0%2C%22font_setting%22%3A0%2C%22k%22%3A0%2C%22k_disable_default%22%3A0%2C%22hlt%22%3A0%2C%22disable_animations%22%3A0%2C%22display_alt_desc%22%3A0%7D; iovoxMCM=other; iovox_sea=eyJmaXJzdF92aXNpdCI6IjIwMjMtMTAtMDdUMTQ6MzA6MDcuOTczWiIsInJlZmVyZXJfcGFnZSI6Imh0dHBzOi8vd3d3LmNhcnMuY29tL3Nob3BwaW5nL2FsYmFueS1ueS8iLCJmaXJzdF9wYWdlIjoiaHR0cHM6Ly93d3cuY2Fycy5jb20vdmVoaWNsZWRldGFpbC9jZjNiMDVkMS1hMjE1LTRiNjAtYTAzYi0yNDU1NDIxZDkzNGMvIn0=; iovox_id=e7697b26-63e4-48db-a842-dfdf013730f2; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~0~...~-1~-1~-1; s_sq=%5B%5BB%5D%5D; _gat_gtag_UA_50492232_1=1; CARS_marketing_source=SFMyNTY.....aG3_Y2mc29_YmtzeWsGdCvPXW-oC-hOpFw2O_r-69oQ; CARS_search_session=SFMyNTY..rhE1p9xZ_mITkZZiRJJhTJQ4XgeezKHRvGXVtSlZu40; _cars_web_key=SFMyNTY.....nvHHdC7NacptxfF_c5V0T7dzpLgEo_6nslJ8p9qXaak; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAnuAMPiKAQAALEWkChXCp4+yh3LfI5kwGkGnfhDrKiijJJ9bOk6zRqaCrcqrHrIJUvfQI1K974MTvwv1NkQ2spiVem5G4H4R2uEs29ogepo5i9Bu0G7v0AFVsKFnOlgjaawa03fpC1b8qzc+vgPIbnWRXGsXnOdJXek65hNHysf+sFyNguZtryXgHO1zjTwGPsX11PowBZXeYqR0NKltEJDG9OIwgnEo8v5YJ2gaPSVakD7ZpaZ+U+8=~1; _ga=GA1.1.1704964458.1696688897; _uetsid=bf8b9a60651d11ee8a3211461756d986; _uetvid=bf8baa30651d11ee8cbea3e331cc35c4; _tq_id.TV-09274518-1.6c07=8508f3f072268ee7.1696688900.0.1696690620..; QSI_HistorySession=https%3A%2F%2Fwww.cars.com%2Fvehicledetail%2F2c4e260f-99b7-45c9-9717-abf38d63d7ff%2F~1696689479141%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690593284%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F~1696690600438%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690602829%7Chttps%3A%2F%2Fwww.cars.com%2F~1696690619648%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2Freviews%2F~1696690620770; smtrrmkr=638322874255987464%5E018b0a8a-05ee-442f-9f6a-bc1ad33a3e3d%5E018b0a8a-05ee-4010-a77c-adff1d21cba3%5E0%5E178.233.76.50; s_lv=1696690624430; s_tslv=1696690624430; _ga_LGBH9NL64W=GS1.1.1696688896.1.1.1696690635.26.0.0; _ga_0SVYF8BFF1=GS1.1.1696688896.1.1.1696690635.0.0.0; s_tp=30139; s_ppv=shopping%2Fsearch-results%2C2%2C2%2C746; _dd_s=rum=0&expire=1696691555863; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~-1~...~0~-1~-1; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; bm_mi=4DB48FCEA082564929365C96D90117DC~~1; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAi4GMfiKAQAAx/iyChU8DMxbL4kPIeroqvx9c1HkhIhOGbQ9q0CFOO2JWbt4gl9MknpZSkQHgyt5CkAItLu+6SoJJJNX38US2dxedDzjEFCPmtoUlG34UZ6T/YSkUL02/NifWUo2KhFwq+AP4I02GZhztgUJ/KdnazYofBXW55PDnmYhAHetRNelepWF0tlc3A/SIYbvtxezuoLiueQADTbLMHhhnePZJKYkNsbrG66kyKTmHIIqtoI=~1; bm_sz=36F39175F590614E19CD893EB952708F~~4342835~3683894; CARS_logged_in=false; CARS_marketing_source=SFMyNTY.....LfRqyl6qj4-emTLjTdmMZw6hsATpoh8pq1fMG8Cra34; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; _cars_web_key=SFMyNTY.....q35LEd4bukElSMyhnvFvEA0rws7y8dKVWxpcXHiR6Gs',
  'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0'
}


# Scraper örneğini oluştur ve çalıştır
scraper = CarsScraper(headers)
scraper.run()
# Out:
# 5968
# 5943
# 5920
# 6059208
# 6060732
# 202201
# 5374999
# 6059205
# 159800
# 187317
# 156714
# 203798
# 156695
# 5374489
# 170877
# 156374
# 5395457
# 182750
# 6059207
# 6096
# 6035740
# 5940
# 5396618
# 5364728
# 6060705
# 159803
# 6060557
# 156370
# 2402305
# 6059804
# 156691
# 180771
# 185337
# 6035392
# 6062296
# 150012
# 189910
# 5388738
# 5392679
# 2391838
# 150126
# 172918
# 5242883
# 180780
# 2560257
# 23921
# 6058282
# 185783
# 5377766
# 5377768
# 5392260
# 196483
# 5391042
# 198676
# 23933
# 194530
# 150063
# 6063475
# 6060934
# 150111
# 5327763
# 2577169
# 5391799
# 186436
# 158760
# 158757
# 5372621
# 85884
# 110094
# 182788
# 26898
# 5376971
# 87872
# 158751
# 6000862
# 5342881
# 6062472
# 6059649
# 192370
# 195001
# 21568
# 21897
# 21891
# 6062277
# 21901
# 5249440
# 148503
# 5371564
# 103720
# 5384021
# 160475
# 5355941
# 101612
# 21887
# 174475
# 196580
# 6058498
# 5380722
# 5389781
# 21933
# 100173
# 5372677
# 1501
# 2530358
# 6060746
# 6000362
# 170617
# 5386879
# 10121
# 5250250
# 83832
# 5397363
# 84606
# 196052
# None
# 6000399
# 6042639
# 111610
# 10095
# 189475
# 191608
# 198694
# 6061867
# 6037285
# 5390677
# 10833
# 105624
# 6060788
# 149245
# 149504
# 10836
# 149238
# 149236
# 6059021
# 6038466
# 149252
# 5396883
# 202323
# 6058816
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\furka\OneDrive\Masaüstü\Python_projects\cars.com Scraping\cars.ipynb Cell 8 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=66'>67</a> # Scraper örneğini oluştur ve çalıştır
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=67'>68</a> scraper = CarsScraper(headers)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=68'>69</a> scraper.run()
#
# c:\Users\furka\OneDrive\Masaüstü\Python_projects\cars.com Scraping\cars.ipynb Cell 8 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=41'>42</a> def run(self):
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=42'>43</a>     for zip_code in self.zip_codes:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=43'>44</a>         customer_ids = self.get_customer_ids(zip_code)
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=44'>45</a>         for customer_id in customer_ids:
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=45'>46</a>             self.request_dealer_page(customer_id)
#
# c:\Users\furka\OneDrive\Masaüstü\Python_projects\cars.com Scraping\cars.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a> def get_customer_ids(self, zip_code, page=1, page_size=100):
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a>     params = {
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a>         "page": str(page),
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=20'>21</a>         "page_size": str(page_size),
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=21'>22</a>         "zip": str(zip_code)
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=22'>23</a>     }
# ---> <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=23'>24</a>     response = requests.request("GET", self.base_url, headers=self.headers, params=params)
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=24'>25</a>     soup = BeautifulSoup(response.content, 'html.parser')
#      <a href='vscode-notebook-cell:/c%3A/Users/furka/OneDrive/Masa%C3%BCst%C3%BC/Python_projects/cars.com%20Scraping/cars.ipynb#W6sZmlsZQ%3D%3D?line=25'>26</a>     a = soup.find("cars-datalayer", attrs={"store": "als"})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     608 """
#     609 A generator wrapper for the read() method. A call will block until
#     610 ``amt`` bytes have been read from the connection or until the
#    (...)
#     621     'content-encoding' header.
#     622 """
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#     626 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\response.py:828, in HTTPResponse.read_chunked(self, amt, decode_content)
#     825     return
#     827 while True:
# --> 828     self._update_chunk_length()
#     829     if self.chunk_left == 0:
#     830         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\response.py:758, in HTTPResponse._update_chunk_length(self)
#     756 if self.chunk_left is not None:
#     757     return
# --> 758 line = self._fp.fp.readline()
#     759 line = line.split(b";", 1)[0]
#     760 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

class CarsScraper:
    def __init__(self, headers):
        self.headers = headers
        self.base_url = "https://www.cars.com/shopping/results/"
        self.dealer_url = "https://www.cars.com/dealers/{customer_id}"
        self.zip_codes = self.load_zip_codes()

    def load_zip_codes(self):
        # ZIP kodlarını CSV dosyasından oku
        df = pd.read_csv('results.csv')
        return df['ZIP Value'].tolist()

    def get_customer_ids(self, zip_code, page_size=100):
        customer_ids = set()
        seen_hrefs = set()
        page = 1

        while True:
            params = {
                "page": str(page),
                "page_size": str(page_size),
                "zip": str(zip_code)
            }
            response = requests.request("GET", self.base_url, headers=self.headers, params=params)
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Sayfadaki href özelliklerini topla
            current_page_hrefs = set(a['href'] for a in soup.find_all('a', class_='vehicle-card-link js-gallery-click-link', href=True))
            
            print(current_page_hrefs)

            # Eğer bu sayfadaki href'ler önceki sayfalarda görülmüşse, döngüyü durdur
            if current_page_hrefs.issubset(seen_hrefs):
                break
            
            # Aksi takdirde, href'leri seen_hrefs kümesine ekle
            seen_hrefs.update(current_page_hrefs)
            
            # Müşteri ID'lerini topla (Eğer müşteri ID'lerini almak istiyorsanız)
            a = soup.find("cars-datalayer", attrs={"store": "als"})
            if a:
                data = json.loads(a.text)
                for entry in data:
                    for vehicle in entry['vehicle_array']:
                        customer_ids.add(vehicle['customer_id'])
            
            # Sayfa numarasını arttır
            page += 1

        return customer_ids

    def request_dealer_page(self, customer_id):
        print(customer_id)
        # url = self.dealer_url.format(customer_id=customer_id)
        # response = requests.request("GET", url, headers=self.headers)
        # İsteğin sonuçlarını işleme
        # ...

    def run(self):
        all_customer_ids = set()  # Tüm müşteri ID'lerini bu kümede topla
        for zip_code in self.zip_codes:
            customer_ids = self.get_customer_ids(zip_code)
            all_customer_ids.update(customer_ids)  # Her ZIP kodu için elde edilen müşteri ID'lerini ekle
        
        for customer_id in all_customer_ids:  # Tüm müşteri ID'leri üzerinden geç
            self.request_dealer_page(customer_id)  # Her müşteri ID'si için dealer sayfasını iste
# Headers tanımı (Örneğin: User-Agent, vs.)
headers = {
  'authority': 'www.cars.com',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'tr-TR,tr;q=0.9',
  'cache-control': 'max-age=0',
  'cookie': 'ToyotaNewAd=false; CARS_als_loaded=true; CARS_experience_testing={"session_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026","tnt_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026.34_0"}; CARS_has_visited=; CARS_logged_in=false; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; bm_sz=F2CC5771C85DE8C2AA6B4A355267D36F~~3293762~3618116; CARS_navClick=; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; s_ecid=MCMID%7C23143105766679683772866057691083138844; AMCVS_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1; _cs_mk_aa=0.022461580964973082_1696688893476; AMCV_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1176715910%7CMCIDTS%7C19638%7CMCMID%7C23143105766679683772866057691083138844%7CMCAID%7CNONE%7CMCOPTOUT-1696696091s%7CNONE%7CMCAAMLH-1697293691%7C6%7CMCAAMB-1697293691%7Cj8Odv6LonN4r3an7LhD3WZrU1bUpAkFkkiY1ncBR96t2PTI%7CMCSYNCSOP%7C411-19645%7CvVersion%7C5.4.0; s_lv_s=First%20Visit; s_inv=0; s_cc=true; _gid=GA1.2.849265699.1696688897; _gcl_au=1.1.2097986781.1696688897; _pin_unauth=dWlkPVltUXdNamN6TmpVdE5tVmtZaTAwTkdSaExUZ3pNVFF0WVdOak5UUXdNbVE0WW1ZMw; ToyotaNewAd=false; di_roxanne__visit_id=8057982562; di_roxanne__visitor_id=12250551822; _aeaid=55e8b292-2da5-4c84-913c-bb19c0ceac90; aelastsite=RVHvE4glMR0sC5iYWBair1aiHO0Ez37924foGSUCRDBlkWrbrSt4Qc%2BBnB7QmaV7; aelreadersettings=%7B%22c_big%22%3A0%2C%22rg%22%3A0%2C%22memph%22%3A0%2C%22contrast_setting%22%3A0%2C%22colorshift_setting%22%3A0%2C%22text_size_setting%22%3A0%2C%22space_setting%22%3A0%2C%22font_setting%22%3A0%2C%22k%22%3A0%2C%22k_disable_default%22%3A0%2C%22hlt%22%3A0%2C%22disable_animations%22%3A0%2C%22display_alt_desc%22%3A0%7D; iovoxMCM=other; iovox_sea=eyJmaXJzdF92aXNpdCI6IjIwMjMtMTAtMDdUMTQ6MzA6MDcuOTczWiIsInJlZmVyZXJfcGFnZSI6Imh0dHBzOi8vd3d3LmNhcnMuY29tL3Nob3BwaW5nL2FsYmFueS1ueS8iLCJmaXJzdF9wYWdlIjoiaHR0cHM6Ly93d3cuY2Fycy5jb20vdmVoaWNsZWRldGFpbC9jZjNiMDVkMS1hMjE1LTRiNjAtYTAzYi0yNDU1NDIxZDkzNGMvIn0=; iovox_id=e7697b26-63e4-48db-a842-dfdf013730f2; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~0~...~-1~-1~-1; s_sq=%5B%5BB%5D%5D; _gat_gtag_UA_50492232_1=1; CARS_marketing_source=SFMyNTY.....aG3_Y2mc29_YmtzeWsGdCvPXW-oC-hOpFw2O_r-69oQ; CARS_search_session=SFMyNTY..rhE1p9xZ_mITkZZiRJJhTJQ4XgeezKHRvGXVtSlZu40; _cars_web_key=SFMyNTY.....nvHHdC7NacptxfF_c5V0T7dzpLgEo_6nslJ8p9qXaak; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAnuAMPiKAQAALEWkChXCp4+yh3LfI5kwGkGnfhDrKiijJJ9bOk6zRqaCrcqrHrIJUvfQI1K974MTvwv1NkQ2spiVem5G4H4R2uEs29ogepo5i9Bu0G7v0AFVsKFnOlgjaawa03fpC1b8qzc+vgPIbnWRXGsXnOdJXek65hNHysf+sFyNguZtryXgHO1zjTwGPsX11PowBZXeYqR0NKltEJDG9OIwgnEo8v5YJ2gaPSVakD7ZpaZ+U+8=~1; _ga=GA1.1.1704964458.1696688897; _uetsid=bf8b9a60651d11ee8a3211461756d986; _uetvid=bf8baa30651d11ee8cbea3e331cc35c4; _tq_id.TV-09274518-1.6c07=8508f3f072268ee7.1696688900.0.1696690620..; QSI_HistorySession=https%3A%2F%2Fwww.cars.com%2Fvehicledetail%2F2c4e260f-99b7-45c9-9717-abf38d63d7ff%2F~1696689479141%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690593284%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F~1696690600438%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690602829%7Chttps%3A%2F%2Fwww.cars.com%2F~1696690619648%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2Freviews%2F~1696690620770; smtrrmkr=638322874255987464%5E018b0a8a-05ee-442f-9f6a-bc1ad33a3e3d%5E018b0a8a-05ee-4010-a77c-adff1d21cba3%5E0%5E178.233.76.50; s_lv=1696690624430; s_tslv=1696690624430; _ga_LGBH9NL64W=GS1.1.1696688896.1.1.1696690635.26.0.0; _ga_0SVYF8BFF1=GS1.1.1696688896.1.1.1696690635.0.0.0; s_tp=30139; s_ppv=shopping%2Fsearch-results%2C2%2C2%2C746; _dd_s=rum=0&expire=1696691555863; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~-1~...~0~-1~-1; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; bm_mi=4DB48FCEA082564929365C96D90117DC~~1; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAi4GMfiKAQAAx/iyChU8DMxbL4kPIeroqvx9c1HkhIhOGbQ9q0CFOO2JWbt4gl9MknpZSkQHgyt5CkAItLu+6SoJJJNX38US2dxedDzjEFCPmtoUlG34UZ6T/YSkUL02/NifWUo2KhFwq+AP4I02GZhztgUJ/KdnazYofBXW55PDnmYhAHetRNelepWF0tlc3A/SIYbvtxezuoLiueQADTbLMHhhnePZJKYkNsbrG66kyKTmHIIqtoI=~1; bm_sz=36F39175F590614E19CD893EB952708F~~4342835~3683894; CARS_logged_in=false; CARS_marketing_source=SFMyNTY.....LfRqyl6qj4-emTLjTdmMZw6hsATpoh8pq1fMG8Cra34; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; _cars_web_key=SFMyNTY.....q35LEd4bukElSMyhnvFvEA0rws7y8dKVWxpcXHiR6Gs',
  'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0'
}


# Scraper örneğini oluştur ve çalıştır
scraper = CarsScraper(headers)
scraper.run()

# %% [markdown]
# # **paralell**

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

class CarsScraper:
    def __init__(self, headers):
        self.results = []
        self.headers = headers
        self.base_url = "https://www.cars.com/shopping/results/"
        self.dealer_url = "https://www.cars.com/dealers/{customer_id}"
        self.zip_codes = self.load_zip_codes()

    def load_zip_codes(self):
        # ZIP kodlarını CSV dosyasından oku
        df = pd.read_csv('results.csv')
        return df['ZIP Value'].tolist()

    def retry_request(self, url, headers, params, max_retries=3, retry_delay=5):
        for attempt in range(max_retries):
            try:
                response = requests.request("GET", url, headers=headers, params=params, timeout=10)
                return response
            except requests.RequestException as e:
                if attempt < max_retries - 1:  # i.e. not the last attempt
                    print(f"Error occurred: {e}. Retrying in {retry_delay} seconds...")
                    time.sleep(retry_delay)
                else:
                    print(f"Error occurred: {e}. No more retries left. Returning None.")
                    return None

    def get_customer_ids(self, zip_code, page_size=100):
        customer_ids = set()
        seen_hrefs = set()
        page = 1

        while True:
            params = {
                "page": str(page),
                "page_size": str(page_size),
                "zip": str(zip_code)
            }
            print(f"Processing page {page} for zip code {zip_code}")  # Hangi sayfa ve ZIP kodunun işlendiğini yazdır

            response = self.retry_request(self.base_url, self.headers, params)
            if response is None:
                print("Failed to fetch the page after retries. Skipping to the next page.")
                continue

            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Sayfadaki href özelliklerini topla
            current_page_hrefs = set(a['href'] for a in soup.find_all('a', class_='vehicle-card-link js-gallery-click-link', href=True))

            # Eğer bu sayfadaki href'ler önceki sayfalarda görülmüşse, döngüyü durdur
            if current_page_hrefs.issubset(seen_hrefs):
                print(f'No new listings on page {page} for zip code {zip_code}. Stopping...')  # Yeni listeleme yok, durduruluyor
                break
            
            # Aksi takdirde, href'leri seen_hrefs kümesine ekle
            seen_hrefs.update(current_page_hrefs)
            
            # Müşteri ID'lerini topla (Eğer müşteri ID'lerini almak istiyorsanız)
            a = soup.find("cars-datalayer", attrs={"store": "als"})
            if a:
                data = json.loads(a.text)
                for entry in data:
                    for vehicle in entry['vehicle_array']:
                        customer_ids.add(vehicle['customer_id'])
            
            time.sleep(0.5)
            
            # Sayfa numarasını arttır
            page += 1
            
        
        print(f'Fetched {len(customer_ids)} customer IDs for zip code {zip_code}.')  # Müşteri ID'leri alındı
        return customer_ids

    def process_zip_code(self, zip_code):
        print(f'Processing zip code {zip_code}...')  # ZIP kodu işleniyor
        customer_ids = self.get_customer_ids(zip_code)
        return customer_ids  # Her ZIP kodu için elde edilen müşteri ID'lerini döndür

    def request_dealer_page(self, customer_id):
        print(f'Requesting dealer page for customer ID {customer_id}...')  # Bayi sayfası isteniyor

        url = self.dealer_url.format(customer_id=customer_id)
        response = requests.request("GET", url, headers=self.headers)

        soup = BeautifulSoup(response.content, 'html.parser')
    
        dealer_name = (found := soup.find('h1', class_='sds-heading--1 dealer-heading')) and found.text.strip()

        if not dealer_name:
            return

        # dealer_website'i çekme
        dealer_website_tag = soup.find('a', {'data-connection-intent-id': 'dealer-profile-page-website-transfer'})
        dealer_website = dealer_website_tag['href'] if dealer_website_tag else None

        # dealer_address ve dealer_direction_link'i çekme
        direction_tag = soup.find('a', {'data-connection-intent-id': 'dealer-directions-connection'})
        dealer_direction_link = direction_tag['href'] if direction_tag else None
        dealer_address = direction_tag['aria-label'] if direction_tag else None
        
        # Telefon numaralarını çekme
        result = {
                "dealer_name": dealer_name,
                "dealer_website": dealer_website,
                "dealer_direction_link": dealer_direction_link,
                "dealer_address": dealer_address,
                "URL": response.url.strip()
                }

        phones = soup.find_all("div", class_="dealer-phone")

        for phone in phones:
            title = phone.find("span", class_="phone-number-title").text.strip()
            # Eğer title boşsa "Used" olarak değiştir
            if not title:
                title = "Used"
            number = phone.find("a", class_="phone-number").text.strip()
            result[title] = number

        print(result)
        
        self.results.append(result)
        # İsteğin sonuçlarını işleme
        # ...
    def save_to_excel(self, filename="dealers.xlsx"):
        df = pd.DataFrame(self.results)
        df.to_excel(filename, index=False)

    def run(self):
        all_customer_ids = set()  # Tüm müşteri ID'lerini bu kümede topla
        print('Starting to process zip codes...')  # ZIP kodları işlenmeye başlanıyor

        with ThreadPoolExecutor() as executor:
            # Paralel olarak her ZIP kodu için get_customer_ids metodunu çalıştır
            results = executor.map(self.process_zip_code, self.zip_codes)
        
        # Sonuçları all_customer_ids kümesine ekle
        for customer_ids in results:
            all_customer_ids.update(customer_ids)
        
        print('Starting to request dealer pages...')  # Bayi sayfaları istenmeye başlanıyor
        with ThreadPoolExecutor(max_workers=4) as executor:
            executor.map(self.request_dealer_page, all_customer_ids)  # Paralel olarak her müşteri ID'si için dealer sayfasını iste

        self.save_to_excel()

# Headers tanımı (Örneğin: User-Agent, vs.)
headers = {
  'authority': 'www.cars.com',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'tr-TR,tr;q=0.9',
  'cache-control': 'max-age=0',
  'cookie': 'ToyotaNewAd=false; CARS_als_loaded=true; CARS_experience_testing={"session_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026","tnt_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026.34_0"}; CARS_has_visited=; CARS_logged_in=false; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; bm_sz=F2CC5771C85DE8C2AA6B4A355267D36F~~3293762~3618116; CARS_navClick=; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; s_ecid=MCMID%7C23143105766679683772866057691083138844; AMCVS_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1; _cs_mk_aa=0.022461580964973082_1696688893476; AMCV_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1176715910%7CMCIDTS%7C19638%7CMCMID%7C23143105766679683772866057691083138844%7CMCAID%7CNONE%7CMCOPTOUT-1696696091s%7CNONE%7CMCAAMLH-1697293691%7C6%7CMCAAMB-1697293691%7Cj8Odv6LonN4r3an7LhD3WZrU1bUpAkFkkiY1ncBR96t2PTI%7CMCSYNCSOP%7C411-19645%7CvVersion%7C5.4.0; s_lv_s=First%20Visit; s_inv=0; s_cc=true; _gid=GA1.2.849265699.1696688897; _gcl_au=1.1.2097986781.1696688897; _pin_unauth=dWlkPVltUXdNamN6TmpVdE5tVmtZaTAwTkdSaExUZ3pNVFF0WVdOak5UUXdNbVE0WW1ZMw; ToyotaNewAd=false; di_roxanne__visit_id=8057982562; di_roxanne__visitor_id=12250551822; _aeaid=55e8b292-2da5-4c84-913c-bb19c0ceac90; aelastsite=RVHvE4glMR0sC5iYWBair1aiHO0Ez37924foGSUCRDBlkWrbrSt4Qc%2BBnB7QmaV7; aelreadersettings=%7B%22c_big%22%3A0%2C%22rg%22%3A0%2C%22memph%22%3A0%2C%22contrast_setting%22%3A0%2C%22colorshift_setting%22%3A0%2C%22text_size_setting%22%3A0%2C%22space_setting%22%3A0%2C%22font_setting%22%3A0%2C%22k%22%3A0%2C%22k_disable_default%22%3A0%2C%22hlt%22%3A0%2C%22disable_animations%22%3A0%2C%22display_alt_desc%22%3A0%7D; iovoxMCM=other; iovox_sea=eyJmaXJzdF92aXNpdCI6IjIwMjMtMTAtMDdUMTQ6MzA6MDcuOTczWiIsInJlZmVyZXJfcGFnZSI6Imh0dHBzOi8vd3d3LmNhcnMuY29tL3Nob3BwaW5nL2FsYmFueS1ueS8iLCJmaXJzdF9wYWdlIjoiaHR0cHM6Ly93d3cuY2Fycy5jb20vdmVoaWNsZWRldGFpbC9jZjNiMDVkMS1hMjE1LTRiNjAtYTAzYi0yNDU1NDIxZDkzNGMvIn0=; iovox_id=e7697b26-63e4-48db-a842-dfdf013730f2; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~0~...~-1~-1~-1; s_sq=%5B%5BB%5D%5D; _gat_gtag_UA_50492232_1=1; CARS_marketing_source=SFMyNTY.....aG3_Y2mc29_YmtzeWsGdCvPXW-oC-hOpFw2O_r-69oQ; CARS_search_session=SFMyNTY..rhE1p9xZ_mITkZZiRJJhTJQ4XgeezKHRvGXVtSlZu40; _cars_web_key=SFMyNTY.....nvHHdC7NacptxfF_c5V0T7dzpLgEo_6nslJ8p9qXaak; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAnuAMPiKAQAALEWkChXCp4+yh3LfI5kwGkGnfhDrKiijJJ9bOk6zRqaCrcqrHrIJUvfQI1K974MTvwv1NkQ2spiVem5G4H4R2uEs29ogepo5i9Bu0G7v0AFVsKFnOlgjaawa03fpC1b8qzc+vgPIbnWRXGsXnOdJXek65hNHysf+sFyNguZtryXgHO1zjTwGPsX11PowBZXeYqR0NKltEJDG9OIwgnEo8v5YJ2gaPSVakD7ZpaZ+U+8=~1; _ga=GA1.1.1704964458.1696688897; _uetsid=bf8b9a60651d11ee8a3211461756d986; _uetvid=bf8baa30651d11ee8cbea3e331cc35c4; _tq_id.TV-09274518-1.6c07=8508f3f072268ee7.1696688900.0.1696690620..; QSI_HistorySession=https%3A%2F%2Fwww.cars.com%2Fvehicledetail%2F2c4e260f-99b7-45c9-9717-abf38d63d7ff%2F~1696689479141%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690593284%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F~1696690600438%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690602829%7Chttps%3A%2F%2Fwww.cars.com%2F~1696690619648%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2Freviews%2F~1696690620770; smtrrmkr=638322874255987464%5E018b0a8a-05ee-442f-9f6a-bc1ad33a3e3d%5E018b0a8a-05ee-4010-a77c-adff1d21cba3%5E0%5E178.233.76.50; s_lv=1696690624430; s_tslv=1696690624430; _ga_LGBH9NL64W=GS1.1.1696688896.1.1.1696690635.26.0.0; _ga_0SVYF8BFF1=GS1.1.1696688896.1.1.1696690635.0.0.0; s_tp=30139; s_ppv=shopping%2Fsearch-results%2C2%2C2%2C746; _dd_s=rum=0&expire=1696691555863; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~-1~...~0~-1~-1; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; bm_mi=4DB48FCEA082564929365C96D90117DC~~1; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAi4GMfiKAQAAx/iyChU8DMxbL4kPIeroqvx9c1HkhIhOGbQ9q0CFOO2JWbt4gl9MknpZSkQHgyt5CkAItLu+6SoJJJNX38US2dxedDzjEFCPmtoUlG34UZ6T/YSkUL02/NifWUo2KhFwq+AP4I02GZhztgUJ/KdnazYofBXW55PDnmYhAHetRNelepWF0tlc3A/SIYbvtxezuoLiueQADTbLMHhhnePZJKYkNsbrG66kyKTmHIIqtoI=~1; bm_sz=36F39175F590614E19CD893EB952708F~~4342835~3683894; CARS_logged_in=false; CARS_marketing_source=SFMyNTY.....LfRqyl6qj4-emTLjTdmMZw6hsATpoh8pq1fMG8Cra34; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; _cars_web_key=SFMyNTY.....q35LEd4bukElSMyhnvFvEA0rws7y8dKVWxpcXHiR6Gs',
  'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0'
}


# Scraper örneğini oluştur ve çalıştır
scraper = CarsScraper(headers)
scraper.run()
# Out:
# Starting to process zip codes...
# Processing zip code 12206...
# Processing page 1 for zip code 12206
# Processing zip code 87151...
# Processing page 1 for zip code 87151
# Processing zip code 99577...
# Processing page 1 for zip code 99577
# Processing zip code 76015...
# Processing page 1 for zip code 76015
# Processing zip code 28815...
# Processing page 1 for zip code 28815
# Processing zip code 30602...
# Processing page 1 for zip code 30602
# Processing zip code 30371...
# Processing page 1 for zip code 30371
# Processing zip code 78763...
# Processing page 1 for zip code 78763
# Processing zip code 93304...
# Processing page 1 for zip code 93304
# Processing zip code 63022...
# Processing page 1 for zip code 63022
# Processing zip code 21298...
# Processing page 1 for zip code 21298
# Processing zip code 70822...
# Processing page 1 for zip code 70822
# Processing zip code 77522...
# Processing page 1 for zip code 77522
# Processing zip code 44146...
# Processing page 1 for zip code 44146
# Processing zip code 98007...
# Processing page 1 for zip code 98007
# Processing zip code 35259...
# Processing page 1 for zip code 35259
# Processing page 2 for zip code 93304
# Processing zip code 83756...
# Processing page 1 for zip code 83756
# Processing page 2 for zip code 87151
# Processing page 2 for zip code 35259
# Processing page 2 for zip code 30602
# Processing page 2 for zip code 12206
# Processing page 2 for zip code 21298
# Processing page 2 for zip code 78763
# Processing page 2 for zip code 77522
# Processing page 2 for zip code 98007
# Processing page 2 for zip code 70822
# Processing page 2 for zip code 76015
# Processing page 2 for zip code 30371
# Processing page 2 for zip code 99577
# Processing page 2 for zip code 28815
# Processing page 2 for zip code 44146
# Processing page 3 for zip code 93304
# Processing page 3 for zip code 35259
# Processing page 3 for zip code 87151
# Processing page 2 for zip code 83756
# Processing page 3 for zip code 12206
# Processing page 3 for zip code 30602
# Processing page 3 for zip code 21298
# Processing page 3 for zip code 78763
# Processing page 3 for zip code 99577
# Processing page 3 for zip code 70822
# Processing page 3 for zip code 77522
# Processing page 4 for zip code 93304
# Processing page 3 for zip code 28815
# Processing page 3 for zip code 30371
# Processing page 3 for zip code 44146
# Processing page 3 for zip code 76015
# Processing page 4 for zip code 87151
# Processing page 3 for zip code 98007
# Processing page 4 for zip code 35259
# Processing page 4 for zip code 30602
# Processing page 4 for zip code 12206
# Processing page 4 for zip code 21298
# Processing page 4 for zip code 78763
# Processing page 4 for zip code 70822
# Processing page 4 for zip code 99577
# Processing page 3 for zip code 83756
# Processing page 4 for zip code 30371
# Processing page 4 for zip code 77522
# Processing page 5 for zip code 93304
# Processing page 4 for zip code 44146
# Processing page 4 for zip code 76015
# Processing page 5 for zip code 87151
# Processing page 4 for zip code 28815
# Processing page 5 for zip code 30602Processing page 5 for zip code 21298
# Processing page 5 for zip code 12206
#
# Processing page 4 for zip code 98007
# Processing page 5 for zip code 35259
# Processing page 5 for zip code 78763
# Processing page 5 for zip code 99577
# Processing page 5 for zip code 70822
# Processing page 5 for zip code 30371
# Processing page 5 for zip code 77522
# Processing page 6 for zip code 93304
# Processing page 4 for zip code 83756
# Processing page 5 for zip code 76015
# Processing page 5 for zip code 44146
# Processing page 5 for zip code 28815
# Processing page 6 for zip code 87151
# Processing page 6 for zip code 35259
# Processing page 6 for zip code 12206
# Processing page 6 for zip code 99577
# Processing page 6 for zip code 30602
# Processing page 5 for zip code 98007
# Processing page 6 for zip code 21298
# Processing page 6 for zip code 30371
# Processing page 6 for zip code 78763
# Processing page 6 for zip code 70822
# Processing page 7 for zip code 93304
# Processing page 5 for zip code 83756
# Processing page 6 for zip code 76015
# Processing page 6 for zip code 77522
# Processing page 7 for zip code 35259Processing page 6 for zip code 28815
#
# Processing page 6 for zip code 44146
# Processing page 7 for zip code 12206
# Processing page 7 for zip code 87151
# Processing page 7 for zip code 99577
# Processing page 7 for zip code 21298
# Processing page 7 for zip code 30602
# Processing page 7 for zip code 70822
# Processing page 7 for zip code 78763
# Processing page 6 for zip code 98007
# Processing page 7 for zip code 30371
# Processing page 8 for zip code 93304
# Processing page 6 for zip code 83756
# Processing page 7 for zip code 77522Processing page 7 for zip code 28815
#
# Processing page 7 for zip code 76015
# Processing page 8 for zip code 35259
# Processing page 8 for zip code 12206
# Processing page 8 for zip code 87151
# Processing page 7 for zip code 44146
# Processing page 8 for zip code 99577
# Processing page 8 for zip code 70822
# Processing page 8 for zip code 30602
# Processing page 9 for zip code 93304
# Processing page 8 for zip code 30371
# Processing page 8 for zip code 78763
# Processing page 7 for zip code 98007
# Processing page 8 for zip code 21298
# Processing page 7 for zip code 83756
# Processing page 9 for zip code 99577
# Processing page 9 for zip code 35259
# Processing page 9 for zip code 12206
# Processing page 9 for zip code 87151
# Processing page 8 for zip code 44146Processing page 8 for zip code 77522
#
# Processing page 8 for zip code 28815
# Processing page 10 for zip code 93304
# Processing page 9 for zip code 30371
# Processing page 9 for zip code 78763
# Processing page 8 for zip code 76015
# Processing page 9 for zip code 70822
# Processing page 9 for zip code 30602
# Processing page 8 for zip code 83756
# Processing page 8 for zip code 98007
# Processing page 9 for zip code 21298
# Processing page 10 for zip code 87151
# Processing page 10 for zip code 12206
# Processing page 10 for zip code 99577
# Processing page 10 for zip code 35259
# Processing page 9 for zip code 77522
# Processing page 9 for zip code 44146
# Processing zip code 39043...
# Processing page 1 for zip code 39043
# Processing zip code 11226...
# Processing page 1 for zip code 11226
# Processing page 11 for zip code 93304
# Processing page 9 for zip code 28815
# Processing page 10 for zip code 30371
# Processing page 10 for zip code 70822
# Processing page 10 for zip code 78763
# Processing page 9 for zip code 83756
# Processing page 10 for zip code 30602
# Processing page 9 for zip code 98007
# Processing page 2 for zip code 39043
# Processing page 9 for zip code 76015
# Processing page 10 for zip code 44146
# Processing page 2 for zip code 11226
# Processing page 12 for zip code 93304Processing page 11 for zip code 30371
#
# Processing page 10 for zip code 21298
# Processing page 10 for zip code 77522
# Processing page 11 for zip code 35259
# Processing page 10 for zip code 28815
# Processing page 11 for zip code 70822
# Processing page 11 for zip code 78763
# Processing page 10 for zip code 83756
# Processing page 11 for zip code 30602
# Processing page 3 for zip code 39043
# Processing page 10 for zip code 76015
# Processing page 10 for zip code 98007
# Processing page 12 for zip code 30371
# Processing page 11 for zip code 21298
# Processing page 13 for zip code 93304
# Processing page 12 for zip code 35259
# Processing page 12 for zip code 70822
# Processing page 11 for zip code 77522
# Processing page 11 for zip code 44146
# Processing page 11 for zip code 28815
# Processing page 3 for zip code 11226
# Processing page 12 for zip code 78763
# Processing page 12 for zip code 30602
# Processing page 13 for zip code 70822
# Processing page 13 for zip code 30371
# Processing page 4 for zip code 39043
# Processing page 13 for zip code 35259
# Processing page 12 for zip code 28815
# Processing page 12 for zip code 77522
# Processing page 12 for zip code 44146
# Processing page 14 for zip code 93304
# Processing page 11 for zip code 83756
# Processing page 11 for zip code 76015Processing page 4 for zip code 11226
#
# Processing page 11 for zip code 98007
# Processing page 12 for zip code 21298
# Processing page 13 for zip code 78763
# Processing page 13 for zip code 30602
# Processing page 14 for zip code 70822
# Processing page 14 for zip code 30371Processing page 5 for zip code 39043
#
# Processing page 14 for zip code 35259
# Processing page 15 for zip code 93304
# Processing page 13 for zip code 28815
# Processing page 13 for zip code 77522
# Processing page 14 for zip code 30602
# Processing page 15 for zip code 70822
# Processing page 12 for zip code 83756
# Processing page 5 for zip code 11226
# Processing page 13 for zip code 21298
# Processing page 12 for zip code 76015
# Processing page 12 for zip code 98007
# Processing page 13 for zip code 44146
# Processing page 14 for zip code 78763
# Processing page 16 for zip code 93304
# Processing page 6 for zip code 39043
# Processing page 15 for zip code 30371
# Processing page 15 for zip code 35259
# Processing page 14 for zip code 28815
# Processing page 14 for zip code 77522
# Processing page 13 for zip code 83756
# Processing page 16 for zip code 70822
# Processing page 6 for zip code 11226
# Processing page 15 for zip code 30602
# Processing page 13 for zip code 98007
# Processing page 14 for zip code 21298
# Processing page 17 for zip code 93304
# Processing page 13 for zip code 76015
# Processing page 7 for zip code 39043
# Processing page 15 for zip code 78763
# Processing page 14 for zip code 44146
# Processing page 16 for zip code 30371
# Processing page 16 for zip code 35259
# Processing page 15 for zip code 77522
# Processing page 17 for zip code 70822
# Processing page 15 for zip code 28815
# Processing page 14 for zip code 83756
# Processing page 16 for zip code 30602
# Processing page 7 for zip code 11226
# Processing page 18 for zip code 93304
# Processing page 16 for zip code 78763
# Processing page 8 for zip code 39043
# Processing page 15 for zip code 21298
# Processing page 14 for zip code 98007
# Processing page 14 for zip code 76015
# Processing page 15 for zip code 44146
# Processing page 17 for zip code 30371
# Processing page 16 for zip code 77522
# Processing page 17 for zip code 35259
# Processing page 18 for zip code 70822Processing page 16 for zip code 28815
#
# Processing page 17 for zip code 30602
# Processing page 15 for zip code 83756
# Processing page 8 for zip code 11226
# Processing page 19 for zip code 93304
# Processing page 17 for zip code 78763
# Processing page 9 for zip code 39043
# No new listings on page 17 for zip code 30602. Stopping...
# Fetched 21 customer IDs for zip code 30602.
# Processing zip code 90624...
# Processing page 1 for zip code 90624
# Processing page 15 for zip code 98007
# Processing page 16 for zip code 21298
# Processing page 15 for zip code 76015
# Processing page 16 for zip code 44146Processing zip code 80155...
# Processing page 1 for zip code 80155
#
# Processing page 17 for zip code 77522
# Processing page 18 for zip code 35259
# Processing page 18 for zip code 30371
# Processing page 16 for zip code 83756
# Processing page 10 for zip code 39043
# Processing page 19 for zip code 70822
# Processing page 20 for zip code 93304Processing page 18 for zip code 78763
#
# Processing page 17 for zip code 28815
# Processing page 9 for zip code 11226
# Processing page 2 for zip code 90624
# Processing page 16 for zip code 98007
# Processing page 17 for zip code 21298
# Processing page 2 for zip code 80155Processing page 17 for zip code 44146
#
# Processing page 16 for zip code 76015
# Processing page 18 for zip code 77522
# Processing page 19 for zip code 30371
# Processing page 19 for zip code 35259
# Processing page 19 for zip code 78763
# Processing page 11 for zip code 39043
# Processing page 21 for zip code 93304
# Processing page 20 for zip code 70822Processing page 17 for zip code 83756
#
# Processing page 10 for zip code 11226
# Processing page 17 for zip code 98007
# Processing page 18 for zip code 28815
# Processing page 3 for zip code 90624
# Processing page 17 for zip code 76015
# Processing page 18 for zip code 44146
# Processing page 20 for zip code 30371
# Processing page 19 for zip code 77522
# Processing page 20 for zip code 35259
# Processing page 3 for zip code 80155
# Processing page 18 for zip code 21298
# Processing page 12 for zip code 39043
# Processing page 20 for zip code 78763
# Processing page 21 for zip code 70822
# Processing page 22 for zip code 93304
# Processing page 18 for zip code 98007
# Processing page 19 for zip code 28815
# Processing zip code 48015...
# Processing page 1 for zip code 48015
# Processing page 11 for zip code 11226
# Processing page 4 for zip code 90624
# Processing page 20 for zip code 77522
# Processing page 19 for zip code 44146
# Processing page 21 for zip code 30371
# Processing page 18 for zip code 76015
# Processing page 18 for zip code 83756
# Processing page 21 for zip code 35259
# Processing page 4 for zip code 80155
# Processing page 23 for zip code 93304
# Processing page 19 for zip code 21298
# Processing page 13 for zip code 39043
# Processing page 12 for zip code 11226
# Processing page 2 for zip code 48015
# Processing page 22 for zip code 70822
# Processing page 20 for zip code 28815
# Processing page 5 for zip code 90624
# Processing page 19 for zip code 98007
# Processing page 21 for zip code 77522
# Processing page 5 for zip code 80155
# Processing page 22 for zip code 30371
# Processing page 20 for zip code 44146
# Processing page 22 for zip code 35259
# Processing page 19 for zip code 76015
# Processing page 24 for zip code 93304
# Processing page 19 for zip code 83756
# Processing page 13 for zip code 11226
# Processing page 20 for zip code 98007
# Processing page 20 for zip code 21298
# Processing page 14 for zip code 39043
# Processing page 23 for zip code 70822
# Processing page 3 for zip code 48015
# Processing page 21 for zip code 28815
# Processing page 6 for zip code 90624
# Processing page 25 for zip code 93304
# Processing page 23 for zip code 35259
# Processing page 23 for zip code 30371
# Processing page 20 for zip code 76015
# Processing page 22 for zip code 77522
# Processing page 6 for zip code 80155
# Processing page 21 for zip code 44146
# Processing page 26 for zip code 93304
# Processing page 20 for zip code 83756
# Processing page 14 for zip code 11226
# Processing page 15 for zip code 39043
# Processing page 24 for zip code 70822
# Processing page 21 for zip code 98007Processing page 21 for zip code 21298
#
# Processing page 4 for zip code 48015
# Processing page 24 for zip code 35259
# Processing page 24 for zip code 30371
# Processing page 7 for zip code 80155
# No new listings on page 26 for zip code 93304. Stopping...
# Fetched 29 customer IDs for zip code 93304.
# Processing zip code 90703...
# Processing page 1 for zip code 90703
# Processing page 23 for zip code 77522
# Processing page 22 for zip code 28815
# Processing page 7 for zip code 90624Processing page 21 for zip code 76015
#
# Processing page 22 for zip code 44146
# Processing page 16 for zip code 39043
# Processing page 21 for zip code 83756
# Processing page 15 for zip code 11226
# Processing page 5 for zip code 48015
# Processing page 8 for zip code 80155
# Processing page 25 for zip code 70822
# Processing page 24 for zip code 77522
# Processing page 25 for zip code 30371
# Processing page 22 for zip code 98007
# Processing page 25 for zip code 35259
# Processing page 22 for zip code 21298
# Processing page 2 for zip code 90703
# Processing page 17 for zip code 39043
# Processing page 23 for zip code 44146
# Processing page 23 for zip code 28815
# Processing page 8 for zip code 90624
# Processing page 22 for zip code 76015
# Processing page 22 for zip code 83756
# Processing page 16 for zip code 11226
# Processing page 6 for zip code 48015
# Processing page 9 for zip code 80155
# Processing page 26 for zip code 35259
# Processing page 23 for zip code 98007
# Processing page 25 for zip code 77522
# Processing page 26 for zip code 70822
# Processing page 3 for zip code 90703
# Processing page 26 for zip code 30371
# Processing page 18 for zip code 39043
# Processing page 24 for zip code 28815
# Processing page 23 for zip code 76015
# Processing page 23 for zip code 21298
# Processing page 23 for zip code 83756
# Processing page 24 for zip code 44146
# Processing page 17 for zip code 11226
# Processing page 27 for zip code 35259
# Processing page 9 for zip code 90624
# Processing page 24 for zip code 98007
# Processing page 26 for zip code 77522
# Processing page 10 for zip code 80155
# Processing page 27 for zip code 70822
# Processing page 4 for zip code 90703
# Processing page 7 for zip code 48015
# Processing page 27 for zip code 30371
# Processing page 19 for zip code 39043
# Processing page 25 for zip code 44146
# Processing page 24 for zip code 83756Processing page 25 for zip code 28815
#
# Processing page 18 for zip code 11226
# Processing page 24 for zip code 21298
# Processing page 24 for zip code 76015
# Processing page 27 for zip code 77522
# Processing page 28 for zip code 35259
# Processing page 11 for zip code 80155
# Processing page 10 for zip code 90624
# Processing page 25 for zip code 98007
# Processing page 20 for zip code 39043Processing page 5 for zip code 90703
#
# Processing page 8 for zip code 48015
# Processing page 28 for zip code 70822
# Processing page 28 for zip code 30371
# Processing page 26 for zip code 28815
# Processing page 26 for zip code 44146
# Processing page 25 for zip code 83756
# Processing page 25 for zip code 21298
# Processing page 19 for zip code 11226
# Processing page 25 for zip code 76015
# Processing page 28 for zip code 77522
# Processing page 12 for zip code 80155
# Processing page 26 for zip code 98007
# Processing page 29 for zip code 35259
# Processing page 29 for zip code 70822
# Processing page 11 for zip code 90624
# Processing page 27 for zip code 28815
# Processing page 6 for zip code 90703
# Processing page 9 for zip code 48015
# Processing page 29 for zip code 30371
# Processing page 21 for zip code 39043
# Processing page 26 for zip code 21298
# Processing page 29 for zip code 77522
# Processing page 26 for zip code 83756
# Processing page 27 for zip code 44146
# Processing page 20 for zip code 11226
# Processing page 26 for zip code 76015
# Processing page 13 for zip code 80155
# Processing page 30 for zip code 70822
# Processing page 27 for zip code 98007
# Processing page 12 for zip code 90624
# Processing page 30 for zip code 35259
# Processing page 28 for zip code 28815
# Processing page 10 for zip code 48015
# Processing page 22 for zip code 39043
# Processing page 30 for zip code 77522
# Processing page 30 for zip code 30371
# Processing page 27 for zip code 83756
# Processing page 7 for zip code 90703
# Processing page 28 for zip code 44146
# Processing page 14 for zip code 80155
# Processing page 21 for zip code 11226
# Processing page 28 for zip code 98007
# Processing page 27 for zip code 21298
# Processing page 27 for zip code 76015
# Processing page 31 for zip code 70822
# Processing page 31 for zip code 35259Processing page 13 for zip code 90624
#
# Processing page 29 for zip code 28815
# Processing page 28 for zip code 83756
# Processing page 31 for zip code 30371
# Processing page 8 for zip code 90703
# Processing page 31 for zip code 77522
# Processing page 23 for zip code 39043
# Processing page 11 for zip code 48015
# Processing page 29 for zip code 44146
# Processing page 15 for zip code 80155
# Processing page 22 for zip code 11226
# Processing page 28 for zip code 76015
# Processing page 29 for zip code 98007
# Processing page 32 for zip code 70822
# Processing page 32 for zip code 35259
# Processing page 30 for zip code 28815
# Processing page 28 for zip code 21298
# Processing page 14 for zip code 90624
# Processing page 32 for zip code 30371
# Processing page 24 for zip code 39043
# Processing page 29 for zip code 83756
# Processing page 32 for zip code 77522
# Processing page 12 for zip code 48015
# Processing page 9 for zip code 90703
# Processing page 31 for zip code 28815
# Processing page 16 for zip code 80155
# Processing page 30 for zip code 44146
# Processing page 23 for zip code 11226
# Processing page 29 for zip code 76015
# Processing page 33 for zip code 35259
# Processing page 33 for zip code 70822
# Processing page 30 for zip code 98007
# Processing page 25 for zip code 39043
# Processing page 29 for zip code 21298
# Processing page 15 for zip code 90624
# Processing page 33 for zip code 77522Processing page 33 for zip code 30371
#
# No new listings on page 31 for zip code 28815. Stopping...
# Fetched 30 customer IDs for zip code 28815.
# Processing zip code 28230...
# Processing page 1 for zip code 28230
# Processing page 30 for zip code 83756
# Processing page 13 for zip code 48015
# Processing page 10 for zip code 90703
# Processing page 31 for zip code 44146
# Processing page 24 for zip code 11226
# Processing page 17 for zip code 80155
# Processing page 34 for zip code 70822
# Processing page 30 for zip code 76015
# Processing page 31 for zip code 98007
# Processing page 26 for zip code 39043
# Processing page 34 for zip code 35259
# Processing zip code 37406...
# Processing page 1 for zip code 37406
# Processing zip code 60608...
# Processing page 1 for zip code 60608
# Processing zip code 45275...
# Processing page 1 for zip code 45275
# Processing page 30 for zip code 21298
# Processing page 16 for zip code 90624
# Processing page 34 for zip code 77522
# Processing page 34 for zip code 30371
# Processing page 11 for zip code 90703
# Processing page 25 for zip code 11226
# Processing page 32 for zip code 44146
# Processing page 18 for zip code 80155
# Processing page 35 for zip code 70822
# Processing page 32 for zip code 98007
# Processing page 31 for zip code 76015
# Processing zip code 44197...
# Processing page 1 for zip code 44197
# Processing page 2 for zip code 60608
# Processing page 2 for zip code 37406
# Processing page 2 for zip code 45275
# Processing page 31 for zip code 21298
# Processing page 35 for zip code 35259
# Processing page 17 for zip code 90624
# Processing page 35 for zip code 77522
# Processing page 35 for zip code 30371
# Processing page 33 for zip code 44146
# Processing page 19 for zip code 80155
# Processing page 12 for zip code 90703
# Processing page 36 for zip code 70822
# Processing page 26 for zip code 11226
# Processing page 32 for zip code 76015
# Processing page 33 for zip code 98007
# Processing page 3 for zip code 60608
# Processing page 2 for zip code 44197
# Processing page 3 for zip code 45275
# Processing page 32 for zip code 21298
# Processing page 36 for zip code 35259
# Processing page 36 for zip code 77522
# Processing page 3 for zip code 37406
# Processing page 36 for zip code 30371
# Processing page 18 for zip code 90624
# Processing page 34 for zip code 98007
# Processing page 20 for zip code 80155
# Processing page 34 for zip code 44146
# Processing page 27 for zip code 11226
# Processing page 13 for zip code 90703
# Processing page 33 for zip code 76015
# Processing page 37 for zip code 70822
# Processing page 3 for zip code 44197
# Processing page 33 for zip code 21298
# Processing page 4 for zip code 45275
# Processing page 37 for zip code 77522
# Processing page 4 for zip code 60608
# Processing page 37 for zip code 35259
# Processing page 4 for zip code 37406
# Processing page 19 for zip code 90624
# Processing page 37 for zip code 30371
# Processing page 35 for zip code 98007
# Processing page 21 for zip code 80155
# Processing page 35 for zip code 44146
# Processing page 14 for zip code 90703
# Processing page 38 for zip code 70822
# Processing page 34 for zip code 76015Processing page 28 for zip code 11226
#
# Processing page 4 for zip code 44197
# Processing page 5 for zip code 45275
# Processing page 34 for zip code 21298
# Processing page 5 for zip code 60608
# Processing page 38 for zip code 77522
# Processing page 5 for zip code 37406
# Processing page 38 for zip code 35259
# Processing page 20 for zip code 90624
# Processing page 39 for zip code 70822
# Processing page 38 for zip code 30371
# Processing page 22 for zip code 80155
# Processing page 15 for zip code 90703
# Processing page 36 for zip code 98007Processing page 36 for zip code 44146
#
# Processing page 5 for zip code 44197
# Processing page 6 for zip code 45275
# Processing page 39 for zip code 77522
# Processing page 35 for zip code 76015Processing page 29 for zip code 11226
# Processing page 6 for zip code 60608
#
# Processing page 35 for zip code 21298
# Processing page 39 for zip code 30371
# Processing page 40 for zip code 70822
# Processing page 6 for zip code 37406
# Processing page 21 for zip code 90624
# Processing page 39 for zip code 35259
# Processing page 23 for zip code 80155
# Processing page 37 for zip code 44146
# Processing page 16 for zip code 90703
# Processing page 6 for zip code 44197
# Processing page 40 for zip code 77522
# Processing page 37 for zip code 98007
# Processing page 7 for zip code 45275
# Processing page 41 for zip code 70822
# Processing page 36 for zip code 76015Processing page 7 for zip code 60608
#
# Processing page 30 for zip code 11226
# Processing page 36 for zip code 21298
# Processing page 40 for zip code 30371
# Processing page 40 for zip code 35259
# Processing page 22 for zip code 90624
# Processing page 7 for zip code 37406
# Processing page 24 for zip code 80155
# Processing page 41 for zip code 77522
# Processing page 7 for zip code 44197
# Processing page 38 for zip code 44146
# Processing page 38 for zip code 98007
# Processing page 17 for zip code 90703
# Processing page 8 for zip code 45275
# Processing page 42 for zip code 70822
# Processing page 41 for zip code 30371
# Processing page 8 for zip code 60608
# Processing page 31 for zip code 11226
# Processing page 37 for zip code 76015
# Processing page 25 for zip code 80155
# Processing page 41 for zip code 35259
# Processing page 37 for zip code 21298Processing page 23 for zip code 90624
#
# Processing page 8 for zip code 37406
# Processing page 42 for zip code 77522
# Processing page 8 for zip code 44197
# Processing page 43 for zip code 70822
# Processing page 39 for zip code 98007Processing page 39 for zip code 44146
#
# Processing page 18 for zip code 90703
# Processing page 9 for zip code 45275
# Processing page 42 for zip code 30371
# Processing page 9 for zip code 60608
# Processing page 42 for zip code 35259
# Processing page 32 for zip code 11226
# Processing page 44 for zip code 70822
# Processing page 26 for zip code 80155
# Processing page 24 for zip code 90624
# Processing page 43 for zip code 77522
# Processing page 38 for zip code 21298
# Processing page 38 for zip code 76015
# Processing page 9 for zip code 44197
# Processing page 9 for zip code 37406
# Processing page 40 for zip code 44146
# Processing page 10 for zip code 45275
# Processing page 19 for zip code 90703
# Processing page 43 for zip code 30371
# Processing page 40 for zip code 98007
# Processing page 10 for zip code 60608
# Processing page 43 for zip code 35259
# Processing page 45 for zip code 70822
# Processing page 27 for zip code 80155
# Processing page 33 for zip code 11226
# Processing page 25 for zip code 90624
# Processing page 39 for zip code 21298
# Processing page 46 for zip code 70822
# Processing page 44 for zip code 77522
# Processing page 39 for zip code 76015
# Processing page 10 for zip code 44197
# Processing page 10 for zip code 37406
# Processing page 11 for zip code 45275
# Processing page 20 for zip code 90703
# Processing page 44 for zip code 35259
# Processing page 44 for zip code 30371
# Processing page 28 for zip code 80155
# Processing page 41 for zip code 44146
# Processing page 41 for zip code 98007
# Processing page 34 for zip code 11226
# Processing page 11 for zip code 60608
# Processing page 45 for zip code 77522
# Processing page 26 for zip code 90624
# Processing page 47 for zip code 70822
# Processing page 40 for zip code 21298
# Processing page 12 for zip code 45275
# Processing page 11 for zip code 44197
# Processing page 21 for zip code 90703
# Processing page 45 for zip code 35259
# Processing page 11 for zip code 37406
# Processing page 40 for zip code 76015
# Processing page 29 for zip code 80155
# Processing page 45 for zip code 30371
# Processing page 42 for zip code 98007
# Processing page 42 for zip code 44146
# Processing page 12 for zip code 60608
# Processing page 46 for zip code 77522
# Processing page 35 for zip code 11226
# Processing page 48 for zip code 70822
# Processing page 13 for zip code 45275
# Processing page 41 for zip code 21298
# Processing page 27 for zip code 90624
# Processing page 12 for zip code 44197
# Processing page 22 for zip code 90703
# Processing page 41 for zip code 76015
# Processing page 46 for zip code 35259
# Processing page 46 for zip code 30371
# Processing page 30 for zip code 80155
# Processing page 12 for zip code 37406
# Processing zip code 80941...
# Processing page 1 for zip code 80941
# Processing zip code 29219...
# Processing page 1 for zip code 29219
# Processing zip code 43201...
# Processing page 1 for zip code 43201
# Processing page 43 for zip code 98007
# Processing page 43 for zip code 44146
# Processing page 49 for zip code 70822
# Processing zip code 94519...
# Processing page 1 for zip code 94519
# Processing page 14 for zip code 45275
# Processing zip code 72035...
# Processing page 1 for zip code 72035
# Processing zip code 78411...
# Processing page 1 for zip code 78411
# Processing page 47 for zip code 35259
# Processing page 42 for zip code 76015
# Processing zip code 75371...
# Processing page 1 for zip code 75371
# Processing zip code 1923...
# Processing page 1 for zip code 1923
# Processing page 23 for zip code 90703Processing zip code 80238...
# Processing page 1 for zip code 80238
#
# Processing page 47 for zip code 30371
# Processing zip code 50393...
# Processing page 1 for zip code 50393
# Processing zip code 92020...
# Processing page 1 for zip code 92020
# Processing zip code 79996...
# Processing page 1 for zip code 79996
# Processing page 31 for zip code 80155
# Processing page 13 for zip code 37406
# Processing page 2 for zip code 78411
# Processing page 15 for zip code 45275
# Processing page 2 for zip code 72035
# Processing page 2 for zip code 94519
# Processing page 48 for zip code 35259
# Processing zip code 95759...
# Processing page 1 for zip code 95759
# Processing page 2 for zip code 1923
# Processing page 2 for zip code 75371
# Processing page 48 for zip code 30371Processing page 24 for zip code 90703
#
# Processing page 2 for zip code 50393
# Processing page 2 for zip code 80238
# Processing page 2 for zip code 79996
# Processing page 32 for zip code 80155
# Processing page 14 for zip code 37406
# Processing page 43 for zip code 76015
# Processing page 2 for zip code 92020
# Processing page 3 for zip code 78411
# Processing page 2 for zip code 95759
# Processing page 49 for zip code 35259
# Processing page 3 for zip code 94519
# Processing page 16 for zip code 45275
# Processing page 3 for zip code 1923
# Processing page 3 for zip code 75371
# Processing page 49 for zip code 30371
# Processing page 3 for zip code 50393
# Processing page 25 for zip code 90703
# Processing page 4 for zip code 1923
# Processing page 33 for zip code 80155
# Processing page 3 for zip code 80238
# Processing page 50 for zip code 35259
# Processing page 15 for zip code 37406
# Processing page 4 for zip code 78411Processing page 44 for zip code 76015
#
# Processing page 3 for zip code 79996Processing page 4 for zip code 94519
#
# Processing page 3 for zip code 95759
# Processing page 17 for zip code 45275
# Processing page 4 for zip code 75371
# Processing page 3 for zip code 92020
# Processing page 50 for zip code 30371

# %% [markdown]
# # paralelsiz

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd


class CarsScraper:
    def __init__(self, headers):
        self.headers = headers
        self.base_url = "https://www.cars.com/shopping/results/"
        self.dealer_url = "https://www.cars.com/dealers/{customer_id}"
        self.zip_codes = self.load_zip_codes()[:1]

    def load_zip_codes(self):
        # ZIP kodlarını CSV dosyasından oku
        df = pd.read_csv('results.csv')
        return df['ZIP Value'].tolist()

    def get_customer_ids(self, zip_code, page_size=100):
        customer_ids = set()
        seen_hrefs = set()
        page = 1

        while True:
            params = {
                "page": str(page),
                "page_size": str(page_size),
                "zip": str(zip_code)
            }
            print(f"Processing page {page} for zip code {zip_code}")  # Hangi sayfa ve ZIP kodunun işlendiğini yazdır
            
            response = requests.request("GET", self.base_url, headers=self.headers, params=params)
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Sayfadaki href özelliklerini topla
            current_page_hrefs = set(a['href'] for a in soup.find_all('a', class_='vehicle-card-link js-gallery-click-link', href=True))

            # Eğer bu sayfadaki href'ler önceki sayfalarda görülmüşse, döngüyü durdur
            if current_page_hrefs.issubset(seen_hrefs):
                print(f'No new listings on page {page} for zip code {zip_code}. Stopping...')  # Yeni listeleme yok, durduruluyor
                break
            
            # Aksi takdirde, href'leri seen_hrefs kümesine ekle
            seen_hrefs.update(current_page_hrefs)
            
            # Müşteri ID'lerini topla (Eğer müşteri ID'lerini almak istiyorsanız)
            a = soup.find("cars-datalayer", attrs={"store": "als"})
            if a:
                data = json.loads(a.text)
                for entry in data:
                    for vehicle in entry['vehicle_array']:
                        customer_ids.add(vehicle['customer_id'])
            
            # Sayfa numarasını arttır
            page += 1
        
        print(f'Fetched {len(customer_ids)} customer IDs for zip code {zip_code}.')  # Müşteri ID'leri alındı
        return customer_ids

    def process_zip_code(self, zip_code):
        print(f'Processing zip code {zip_code}...')  # ZIP kodu işleniyor
        customer_ids = self.get_customer_ids(zip_code)
        return customer_ids  # Her ZIP kodu için elde edilen müşteri ID'lerini döndür

    def request_dealer_page(self, customer_id):
        print(f'Requesting dealer page for customer ID {customer_id}...')  # Bayi sayfası isteniyor

        url = self.dealer_url.format(customer_id=customer_id)
        response = requests.request("GET", url, headers=self.headers)

        soup = BeautifulSoup(response.content, 'html.parser')
    
        dealer_name = (found := soup.find('h1', class_='sds-heading--1 dealer-heading')) and found.text.strip()
        
        # Telefon numaralarını çekme
        result = {"dealer_name": dealer_name}

        phones = soup.find_all("div", class_="dealer-phone")

        for phone in phones:
            title = phone.find("span", class_="phone-number-title").text.strip()
            # Eğer title boşsa "Used" olarak değiştir
            if not title:
                title = "Used"
            number = phone.find("a", class_="phone-number").text.strip()
            result[title] = number

        print(result)
        
        return result

    def save_to_excel(self, results):
        df = pd.DataFrame(results)
        df.to_excel("dealers_data.xlsx", index=False)  # "dealers_data.xlsx" adında bir Excel dosyasına kaydedin


    def run(self):
        all_customer_ids = set()  # Tüm müşteri ID'lerini bu kümede topla
        dealers = []  # Sonuçları toplamak için bir liste oluşturun
        print('Starting to process zip codes...')  # ZIP kodları işlenmeye başlanıyor

        for zip_code in self.zip_codes:
            customer_ids = self.process_zip_code(zip_code)
            all_customer_ids.update(customer_ids)
        
        print('Starting to request dealer pages...')  # Bayi sayfaları istenmeye başlanıyor

        for customer_id in all_customer_ids:
            dealer_results = self.request_dealer_page(customer_id)  # Her müşteri ID'si için dealer sayfasını iste
            dealers.append(dealer_results)
        
        # Sonuçları Excel'e kaydet
        self.save_to_excel(dealers)

# Headers tanımı (Örneğin: User-Agent, vs.)
headers = {
  'authority': 'www.cars.com',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'tr-TR,tr;q=0.9',
  'cache-control': 'max-age=0',
  'cookie': 'ToyotaNewAd=false; CARS_als_loaded=true; CARS_experience_testing={"session_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026","tnt_id":"3d53dc31-6f9c-4ea8-8ad4-bf47d09bb026.34_0"}; CARS_has_visited=; CARS_logged_in=false; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; bm_sz=F2CC5771C85DE8C2AA6B4A355267D36F~~3293762~3618116; CARS_navClick=; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; s_ecid=MCMID%7C23143105766679683772866057691083138844; AMCVS_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1; _cs_mk_aa=0.022461580964973082_1696688893476; AMCV_C78C1CFE532E6E2E0A490D45%40AdobeOrg=1176715910%7CMCIDTS%7C19638%7CMCMID%7C23143105766679683772866057691083138844%7CMCAID%7CNONE%7CMCOPTOUT-1696696091s%7CNONE%7CMCAAMLH-1697293691%7C6%7CMCAAMB-1697293691%7Cj8Odv6LonN4r3an7LhD3WZrU1bUpAkFkkiY1ncBR96t2PTI%7CMCSYNCSOP%7C411-19645%7CvVersion%7C5.4.0; s_lv_s=First%20Visit; s_inv=0; s_cc=true; _gid=GA1.2.849265699.1696688897; _gcl_au=1.1.2097986781.1696688897; _pin_unauth=dWlkPVltUXdNamN6TmpVdE5tVmtZaTAwTkdSaExUZ3pNVFF0WVdOak5UUXdNbVE0WW1ZMw; ToyotaNewAd=false; di_roxanne__visit_id=8057982562; di_roxanne__visitor_id=12250551822; _aeaid=55e8b292-2da5-4c84-913c-bb19c0ceac90; aelastsite=RVHvE4glMR0sC5iYWBair1aiHO0Ez37924foGSUCRDBlkWrbrSt4Qc%2BBnB7QmaV7; aelreadersettings=%7B%22c_big%22%3A0%2C%22rg%22%3A0%2C%22memph%22%3A0%2C%22contrast_setting%22%3A0%2C%22colorshift_setting%22%3A0%2C%22text_size_setting%22%3A0%2C%22space_setting%22%3A0%2C%22font_setting%22%3A0%2C%22k%22%3A0%2C%22k_disable_default%22%3A0%2C%22hlt%22%3A0%2C%22disable_animations%22%3A0%2C%22display_alt_desc%22%3A0%7D; iovoxMCM=other; iovox_sea=eyJmaXJzdF92aXNpdCI6IjIwMjMtMTAtMDdUMTQ6MzA6MDcuOTczWiIsInJlZmVyZXJfcGFnZSI6Imh0dHBzOi8vd3d3LmNhcnMuY29tL3Nob3BwaW5nL2FsYmFueS1ueS8iLCJmaXJzdF9wYWdlIjoiaHR0cHM6Ly93d3cuY2Fycy5jb20vdmVoaWNsZWRldGFpbC9jZjNiMDVkMS1hMjE1LTRiNjAtYTAzYi0yNDU1NDIxZDkzNGMvIn0=; iovox_id=e7697b26-63e4-48db-a842-dfdf013730f2; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~0~...~-1~-1~-1; s_sq=%5B%5BB%5D%5D; _gat_gtag_UA_50492232_1=1; CARS_marketing_source=SFMyNTY.....aG3_Y2mc29_YmtzeWsGdCvPXW-oC-hOpFw2O_r-69oQ; CARS_search_session=SFMyNTY..rhE1p9xZ_mITkZZiRJJhTJQ4XgeezKHRvGXVtSlZu40; _cars_web_key=SFMyNTY.....nvHHdC7NacptxfF_c5V0T7dzpLgEo_6nslJ8p9qXaak; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAnuAMPiKAQAALEWkChXCp4+yh3LfI5kwGkGnfhDrKiijJJ9bOk6zRqaCrcqrHrIJUvfQI1K974MTvwv1NkQ2spiVem5G4H4R2uEs29ogepo5i9Bu0G7v0AFVsKFnOlgjaawa03fpC1b8qzc+vgPIbnWRXGsXnOdJXek65hNHysf+sFyNguZtryXgHO1zjTwGPsX11PowBZXeYqR0NKltEJDG9OIwgnEo8v5YJ2gaPSVakD7ZpaZ+U+8=~1; _ga=GA1.1.1704964458.1696688897; _uetsid=bf8b9a60651d11ee8a3211461756d986; _uetvid=bf8baa30651d11ee8cbea3e331cc35c4; _tq_id.TV-09274518-1.6c07=8508f3f072268ee7.1696688900.0.1696690620..; QSI_HistorySession=https%3A%2F%2Fwww.cars.com%2Fvehicledetail%2F2c4e260f-99b7-45c9-9717-abf38d63d7ff%2F~1696689479141%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690593284%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F~1696690600438%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2F187317%2Fdestination-kia%2F%23Reviews~1696690602829%7Chttps%3A%2F%2Fwww.cars.com%2F~1696690619648%7Chttps%3A%2F%2Fwww.cars.com%2Fdealers%2Freviews%2F~1696690620770; smtrrmkr=638322874255987464%5E018b0a8a-05ee-442f-9f6a-bc1ad33a3e3d%5E018b0a8a-05ee-4010-a77c-adff1d21cba3%5E0%5E178.233.76.50; s_lv=1696690624430; s_tslv=1696690624430; _ga_LGBH9NL64W=GS1.1.1696688896.1.1.1696690635.26.0.0; _ga_0SVYF8BFF1=GS1.1.1696688896.1.1.1696690635.0.0.0; s_tp=30139; s_ppv=shopping%2Fsearch-results%2C2%2C2%2C746; _dd_s=rum=0&expire=1696691555863; _abck=9A88A1203CBFC2CDB9A90DBBF2618196~-1~...~0~-1~-1; ak_bmsc=E7F0BE88D5FC808A0E9BAAD044830816~000000000000000000000000000000~...; bm_mi=4DB48FCEA082564929365C96D90117DC~~1; bm_sv=2C280EFBF8D926AE462A76F83DEA5AA6~YAAQvoYUAi4GMfiKAQAAx/iyChU8DMxbL4kPIeroqvx9c1HkhIhOGbQ9q0CFOO2JWbt4gl9MknpZSkQHgyt5CkAItLu+6SoJJJNX38US2dxedDzjEFCPmtoUlG34UZ6T/YSkUL02/NifWUo2KhFwq+AP4I02GZhztgUJ/KdnazYofBXW55PDnmYhAHetRNelepWF0tlc3A/SIYbvtxezuoLiueQADTbLMHhhnePZJKYkNsbrG66kyKTmHIIqtoI=~1; bm_sz=36F39175F590614E19CD893EB952708F~~4342835~3683894; CARS_logged_in=false; CARS_marketing_source=SFMyNTY.....LfRqyl6qj4-emTLjTdmMZw6hsATpoh8pq1fMG8Cra34; CARS_trip_id=e34b8329-2dbb-4d56-919d-b1853d1f2d5d; _cars_web_key=SFMyNTY.....q35LEd4bukElSMyhnvFvEA0rws7y8dKVWxpcXHiR6Gs',
  'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0'
}


# Scraper örneğini oluştur ve çalıştır
scraper = CarsScraper(headers)
scraper.run()
# Out:
# Starting to process zip codes...
# Processing zip code 12206...
# Processing page 1 for zip code 12206
# Processing page 2 for zip code 12206
# Processing page 3 for zip code 12206
# Processing page 4 for zip code 12206
# Processing page 5 for zip code 12206
# Processing page 6 for zip code 12206
# Processing page 7 for zip code 12206
# Processing page 8 for zip code 12206
# Processing page 9 for zip code 12206
# Processing page 10 for zip code 12206
# Processing page 11 for zip code 12206
# Processing page 12 for zip code 12206
# Processing page 13 for zip code 12206
# Processing page 14 for zip code 12206
# Processing page 15 for zip code 12206
# Processing page 16 for zip code 12206
# Processing page 17 for zip code 12206
# Processing page 18 for zip code 12206
# Processing page 19 for zip code 12206
# Processing page 20 for zip code 12206
# Processing page 21 for zip code 12206
# Processing page 22 for zip code 12206
# Processing page 23 for zip code 12206
# Processing page 24 for zip code 12206
# Processing page 25 for zip code 12206
# Processing page 26 for zip code 12206
# Processing page 27 for zip code 12206
# Processing page 28 for zip code 12206
# Processing page 29 for zip code 12206
# Processing page 30 for zip code 12206
# Processing page 31 for zip code 12206
# Processing page 32 for zip code 12206
# Processing page 33 for zip code 12206
# Processing page 34 for zip code 12206
# Processing page 35 for zip code 12206
# Processing page 36 for zip code 12206
# Processing page 37 for zip code 12206
# Processing page 38 for zip code 12206
# Processing page 39 for zip code 12206
# Processing page 40 for zip code 12206
# Processing page 41 for zip code 12206
# Processing page 42 for zip code 12206
# Processing page 43 for zip code 12206
# Processing page 44 for zip code 12206
# Processing page 45 for zip code 12206
# Processing page 46 for zip code 12206
# Processing page 47 for zip code 12206
# Processing page 48 for zip code 12206
# Processing page 49 for zip code 12206
# Processing page 50 for zip code 12206
# Processing page 51 for zip code 12206
# Processing page 52 for zip code 12206
# Processing page 53 for zip code 12206
# Processing page 54 for zip code 12206
# Processing page 55 for zip code 12206
# Processing page 56 for zip code 12206
# Processing page 57 for zip code 12206
# Processing page 58 for zip code 12206
# Processing page 59 for zip code 12206
# Processing page 60 for zip code 12206
# Processing page 61 for zip code 12206
# Processing page 62 for zip code 12206
# Processing page 63 for zip code 12206
# Processing page 64 for zip code 12206
# Processing page 65 for zip code 12206
# Processing page 66 for zip code 12206
# Processing page 67 for zip code 12206
# Processing page 68 for zip code 12206
# Processing page 69 for zip code 12206
# Processing page 70 for zip code 12206
# Processing page 71 for zip code 12206
# Processing page 72 for zip code 12206
# Processing page 73 for zip code 12206
# Processing page 74 for zip code 12206
# Processing page 75 for zip code 12206
# Processing page 76 for zip code 12206
# Processing page 77 for zip code 12206
# Processing page 78 for zip code 12206
# Processing page 79 for zip code 12206
# Processing page 80 for zip code 12206
# Processing page 81 for zip code 12206
# No new listings on page 81 for zip code 12206. Stopping...
# Fetched 68 customer IDs for zip code 12206.
# Starting to request dealer pages...
# Requesting dealer page for customer ID 6060732...
# {'dealer_name': 'Land Rover Albany', 'New': '(866) 985-2195', 'Used': '(888) 742-5597', 'Service': '(888) 377-4212'}
# Requesting dealer page for customer ID 6093...
# {'dealer_name': 'New Country Toyota', '': '(518) 584-7700'}
# Requesting dealer page for customer ID 156374...
# {'dealer_name': 'Crossroads Ford', 'New': '(518) 244-8249', 'Used': '(518) 244-8260', 'Service': '(518) 244-8257'}
# Requesting dealer page for customer ID 187317...
# {'dealer_name': 'Destination KIA', 'New': '(518) 708-8670', 'Used': '(518) 708-8661', 'Service': '(518) 708-8665'}
# Requesting dealer page for customer ID 5395457...
# {'dealer_name': 'Ford of Latham', 'New': '(518) 203-2389', 'Used': '(518) 203-2388', 'Service': '(518) 874-0669'}
# Requesting dealer page for customer ID 5354875...
# {'dealer_name': 'Bob Karl Sales and Service', '': '(518) 203-2266'}
# Requesting dealer page for customer ID 6096...
# {'dealer_name': 'Saratoga Honda', 'New': '(866) 383-0371', 'Used': '(866) 452-0277', 'Service': '(518) 290-3972'}
# Requesting dealer page for customer ID 6060705...
# {'dealer_name': 'Jaguar Albany', 'New': '(888) 759-8124', 'Used': '(888) 759-5949', 'Service': '(888) 769-2146'}
# Requesting dealer page for customer ID 6035740...
# {'dealer_name': 'DePaula Mazda', 'New': '(518) 708-8683', 'Used': '(518) 801-0759', 'Service': '(518) 708-8648'}
# Requesting dealer page for customer ID 6062401...
# {'dealer_name': 'OD Auto Sales', '': '(802) 823-1010'}
# Requesting dealer page for customer ID 6059804...
# {'dealer_name': 'Chrysler Dodge Jeep Ram of Clifton Park', 'New': '(518) 707-0124', 'Used': '(518) 707-0139', 'Service': '(518) 707-0155'}
# Requesting dealer page for customer ID 6060074...
# {'dealer_name': 'Keeler Pre-owned', 'New': '(518) 362-1392', 'Used': '(518) 362-1385', 'Service': '(518) 362-1391'}
# Requesting dealer page for customer ID 5370485...
# {'dealer_name': 'Broadway Garage', '': '(518) 267-3214'}
# Requesting dealer page for customer ID 5343158...
# {'dealer_name': 'Horning Auto Sales', '': '(518) 631-4883'}
# Requesting dealer page for customer ID 156652...
# {'dealer_name': 'Goldstein Subaru', '': '(518) 690-2241'}
# Requesting dealer page for customer ID 156868...
# {'dealer_name': 'Porsche Clifton Park'}
# Requesting dealer page for customer ID 156691...
# {'dealer_name': 'Audi Albany', 'New': '(518) 608-2054', 'Used': '(518) 690-6819', 'Service': '(518) 244-8259'}
# Requesting dealer page for customer ID 196665...
# {'dealer_name': "Knighton's Auto Services", '': '(518) 213-4376'}
# Requesting dealer page for customer ID 5364728...
# {'dealer_name': 'Exit5 Auto Group', '': '(518) 670-4424'}
# Requesting dealer page for customer ID 156690...
# {'dealer_name': 'Goldstein Chrysler Jeep Dodge RAM', '': '(518) 690-2333'}
# Requesting dealer page for customer ID 156879...
# {'dealer_name': 'Morris Ford', '': '(518) 399-9188'}
# Requesting dealer page for customer ID 5940...
# {'dealer_name': 'Lia Honda of Albany', 'New': '(866) 512-4851', 'Used': '(866) 512-9844', 'Service': '(866) 513-6113'}
# Requesting dealer page for customer ID 190588...
# {'dealer_name': 'Titan Auto Sales', '': '(518) 650-0603'}
# Requesting dealer page for customer ID 6059292...
# {'dealer_name': 'Matthews Kia of Schenectady', 'New': '(518) 631-3910', 'Used': '(518) 631-3908', 'Service': '(518) 901-3324'}
# Requesting dealer page for customer ID 203798...
# {'dealer_name': 'Subaru of Troy', 'New': '(877) 732-8335', 'Used': '(888) 642-9224', 'Service': '(888) 277-6759'}
# Requesting dealer page for customer ID 156576...
# {'dealer_name': 'Goldstein Buick GMC', '': '(518) 690-2515'}
# Requesting dealer page for customer ID 5374999...
# {'dealer_name': 'CarMax Albany - Offering Express Pickup and Home Delivery', '': '(518) 213-3875'}
# Requesting dealer page for customer ID 5930...
# {'dealer_name': 'Cooley Motors', '': '(518) 283-2902'}
# Requesting dealer page for customer ID 5919...
# {'dealer_name': 'Northeast Acura', '': '(518) 785-4105'}
# Requesting dealer page for customer ID 5374489...
# {'dealer_name': 'DePaula Ford', 'New': '(518) 626-8864', 'Used': '(518) 708-8601', 'Service': '(518) 708-8660'}
# Requesting dealer page for customer ID 2402305...
# {'dealer_name': 'Lia Chrysler Jeep Dodge Ram', 'New': '(866) 413-8704', 'Used': '(866) 414-0612', 'Service': '(866) 414-2341'}
# Requesting dealer page for customer ID 170877...
# {'dealer_name': 'DePaula Chevrolet', 'New': '(518) 293-4456', 'Used': '(518) 293-4494', 'Service': '(518) 293-4334'}
# Requesting dealer page for customer ID 6059205...
# {'dealer_name': "Wally's Nissan of Latham", 'New': '(518) 616-0579', 'Used': '(518) 616-0588', 'Service': '(518) 512-0133'}
# Requesting dealer page for customer ID 182750...
# {'dealer_name': 'BMW of South Albany', 'New': '(877) 692-2204', 'Used': '(877) 695-2145', 'Service': '(877) 699-0599'}
# Requesting dealer page for customer ID 156714...
# {'dealer_name': 'Metro Ford', 'New': '(518) 708-8650', 'Used': '(518) 708-8659', 'Service': '(518) 289-4484'}
# Requesting dealer page for customer ID 185430...
# {'dealer_name': "Michael's Auto Plaza", '': '(518) 417-3995'}
# Requesting dealer page for customer ID 5968...
# {'dealer_name': 'Mohawk Honda', 'New': '(518) 557-4143', 'Used': '(518) 348-3741', 'Service': '(518) 707-0169'}
# Requesting dealer page for customer ID 5912...
# {'dealer_name': 'Kinderhook Toyota', '': '(518) 822-9911'}
# Requesting dealer page for customer ID 156575...
# {'dealer_name': 'Destination Nissan', 'New': '(866) 968-7970', 'Used': '(877) 828-8949', 'Service': '(518) 708-8675'}
# Requesting dealer page for customer ID 5354386...
# {'dealer_name': 'The Mercedes-Benz Center at Keeler Motor Car Company', '': '(518) 785-4197'}
# Requesting dealer page for customer ID 6059293...
# {'dealer_name': 'Matthews Hyundai of Schenectady', 'New': '(518) 631-4867', 'Used': '(518) 631-4962', 'Service': '(518) 631-4968'}
# Requesting dealer page for customer ID 5920...
# {'dealer_name': 'Northway Toyota', 'New': '(518) 213-4903', 'Used': '(518) 213-4317', 'Service': '(518) 783-1951'}
# Requesting dealer page for customer ID 5247504...
# {'dealer_name': 'Lia Nissan of Saratoga', 'New': '(518) 633-8781', 'Used': '(518) 633-8780', 'Service': '(518) 633-1017'}
# Requesting dealer page for customer ID 156722...
# {'dealer_name': 'Wedekind Motors', '': '(518) 631-4840'}
# Requesting dealer page for customer ID 5343719...
# {'dealer_name': 'Buy Rite Auto Sales', '': '(518) 708-6942'}
# Requesting dealer page for customer ID 5924...
# {'dealer_name': 'Toyota of Clifton Park', '': '(518) 584-7700'}
# Requesting dealer page for customer ID 5914...
# {'dealer_name': 'Keeler Honda', '': '(866) 796-7362'}
# Requesting dealer page for customer ID 6060557...
# {'dealer_name': 'McGovern Volvo Cars Albany', 'New': '(888) 760-4182', 'Used': '(888) 258-0025', 'Service': '(888) 258-8551'}
# Requesting dealer page for customer ID 5916...
# {'dealer_name': 'Martin Nemer VW of Latham', '': '(518) 785-5581'}
# Requesting dealer page for customer ID 159803...
# {'dealer_name': 'Lia Hyundai of Albany', 'New': '(866) 452-6793', 'Used': '(866) 454-2479', 'Service': '(866) 455-1751'}
# Requesting dealer page for customer ID 5395363...
# {'dealer_name': 'Albany Battery', '': '(518) 801-0753'}
# Requesting dealer page for customer ID 109015...
# {'dealer_name': 'Lia Toyota of Colonie', 'New': '(866) 472-0304', 'Used': '(866) 473-9092', 'Service': '(866) 475-3584'}
# Requesting dealer page for customer ID 5332445...
# {'dealer_name': 'Meredith Motors', '': '(518) 241-1518'}
# Requesting dealer page for customer ID 202201...
# {'dealer_name': 'Verrillo Motor Car Co.', '': '(518) 631-4910'}
# Requesting dealer page for customer ID None...
# {'dealer_name': None}
# Requesting dealer page for customer ID 156647...
# {'dealer_name': 'Otto Cadillac', '': '(518) 869-5000'}
# Requesting dealer page for customer ID 5351216...
# {'dealer_name': 'Super Auto Care Service Inc.', '': '(518) 556-2487'}
# Requesting dealer page for customer ID 156798...
# {'dealer_name': 'Tony Mangino Mitsubishi', 'New': '(518) 631-3729', 'Used': '(518) 631-3856', 'Service': '(518) 631-3405'}
# Requesting dealer page for customer ID 6059207...
# {'dealer_name': "Wally's Ford of East Greenbush", 'New': '(518) 616-0599', 'Used': '(518) 626-8876', 'Service': '(518) 616-0568'}
# Requesting dealer page for customer ID 156370...
# {'dealer_name': 'Marchese Ford, Inc.', 'New': '(877) 754-0252', 'Used': '(877) 468-4816', 'Service': '(877) 585-1301'}
# Requesting dealer page for customer ID 199047...
# {'dealer_name': "Jim's Auto Sales & Service of Glenville, Inc.", '': '(518) 631-5957'}
# Requesting dealer page for customer ID 159800...
# {'dealer_name': 'Lia Nissan of Colonie', 'New': '(866) 309-7875', 'Used': '(866) 349-9881', 'Service': '(866) 481-9867'}
# Requesting dealer page for customer ID 5354418...
# {'dealer_name': 'Keeler BMW', '': '(518) 785-4191'}
# Requesting dealer page for customer ID 5943...
# {'dealer_name': 'DeNooyer Chevrolet', 'New': '(518) 708-8635', 'Used': '(518) 626-8863', 'Service': '(518) 616-0583'}
# Requesting dealer page for customer ID 5396618...
# {'dealer_name': 'Marchese Ford of Mechanicville', 'New': '(518) 539-4103', 'Used': '(518) 289-1052', 'Service': '(518) 289-1193'}
# Requesting dealer page for customer ID 156695...
# {'dealer_name': 'Lia INFINITI', 'New': '(866) 518-3932', 'Used': '(866) 523-9899', 'Service': '(866) 524-1989'}
# Requesting dealer page for customer ID 5936...
# {'dealer_name': 'Rensselaer Honda', 'New': '(518) 279-1171', 'Used': '(518) 279-1171', 'Service': '(518) 629-1048'}
# Requesting dealer page for customer ID 6059208...
# {'dealer_name': 'Volkswagen of Schenectady', 'New': '(518) 387-3789', 'Used': '(518) 707-0161', 'Service': '(518) 631-2782'}
